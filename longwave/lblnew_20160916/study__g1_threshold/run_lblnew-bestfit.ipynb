# %%
import os
import sys
import shutil
import pprint
import importlib

import climatools.lblnew.setup_bestfit as setup_bestfit
import climatools.lblnew.bestfit_params as bestfit
import climatools.lblnew.pipeline as pipeline

importlib.reload(setup_bestfit)
importlib.reload(bestfit)
importlib.reload(pipeline)
# Out:
# <module 'climatools.lblnew.pipeline' from '/chia_cluster/home/jackyu/climatools/climatools/lblnew/pipeline.py'>

# %%
def params_bestfit():
    params = []   

    molecules = ['h2o', 'co2', 'n2o']
    band = '3a'
#    molecules = ['ch4']
#    band = '7'
    
    atmpros = [('mls', 294), ('saw', 257), ('trp', 300)]
    
    for molecule in molecules:
        for atmpro, tsfc in atmpros:
            param = bestfit.kdist_params(molecule=molecule, band=band)
            param['atmpro'] = atmpro
            param['tsfc'] = tsfc
            param['option_compute_ktable'] = 0
            param['commitnumber'] = param['commitnumber'] + '_testbsub'
            params.append(param)
        
    return params

# %%
params = params_bestfit()

# %%
pipeline.pipeline_fortran_bsub(params=params, setup=setup_bestfit)

# %%
# !bjobs
# Out:
# No unfinished job found

# %%
gprocs = pipeline.pipeline_ipynb2git(params=params, 
                                     setup=setup_bestfit)
# Out:
# {'atmpro': 'mls',
#  'band': '3a',
#  'commitnumber': 'a06b618_testbsub',
#  'conc': None,
#  'dv': 0.001,
#  'klin': 0,
#  'molecule': 'h2o',
#  'ng_adju': [0, 0],
#  'ng_refs': [2, 6],
#  'nv': 1000,
#  'option_compute_btable': 0,
#  'option_compute_ktable': 0,
#  'option_wgt_flux': 1,
#  'option_wgt_k': 1,
#  'ref_pts': [(10, 250), (600, 250)],
#  'tsfc': 294,
#  'vmax': 620,
#  'vmin': 540,
#  'w_diffuse': [(1.9, 1.7), (1.4, 1.4, 1.4, 1.55, 1.6, 1.66)],
#  'wgt': [(0.7, 0.7), (0.7, 0.5, 0.5, 0.5, 0.5, 0.5)]}
#
# {'atmpro': 'saw',
#  'band': '3a',
#  'commitnumber': 'a06b618_testbsub',
#  'conc': None,
#  'dv': 0.001,
#  'klin': 0,
#  'molecule': 'h2o',
#  'ng_adju': [0, 0],
#  'ng_refs': [2, 6],
#  'nv': 1000,
#  'option_compute_btable': 0,
#  'option_compute_ktable': 0,
#  'option_wgt_flux': 1,
#  'option_wgt_k': 1,
#  'ref_pts': [(10, 250), (600, 250)],
#  'tsfc': 257,
#  'vmax': 620,
#  'vmin': 540,
#  'w_diffuse': [(1.9, 1.7), (1.4, 1.4, 1.4, 1.55, 1.6, 1.66)],
#  'wgt': [(0.7, 0.7), (0.7, 0.5, 0.5, 0.5, 0.5, 0.5)]}
#
# {'atmpro': 'trp',
#  'band': '3a',
#  'commitnumber': 'a06b618_testbsub',
#  'conc': None,
#  'dv': 0.001,
#  'klin': 0,
#  'molecule': 'h2o',
#  'ng_adju': [0, 0],
#  'ng_refs': [2, 6],
#  'nv': 1000,
#  'option_compute_btable': 0,
#  'option_compute_ktable': 0,
#  'option_wgt_flux': 1,
#  'option_wgt_k': 1,
#  'ref_pts': [(10, 250), (600, 250)],
#  'tsfc': 300,
#  'vmax': 620,
#  'vmin': 540,
#  'w_diffuse': [(1.9, 1.7), (1.4, 1.4, 1.4, 1.55, 1.6, 1.66)],
#  'wgt': [(0.7, 0.7), (0.7, 0.5, 0.5, 0.5, 0.5, 0.5)]}
#
# {'atmpro': 'mls',
#  'band': '3a',
#  'commitnumber': 'a06b618_testbsub',
#  'conc': 0.0004,
#  'dv': 0.001,
#  'klin': 6.375563e-24,
#  'molecule': 'co2',
#  'ng_adju': [0, 0, 0],
#  'ng_refs': [3, 2, 4],
#  'nv': 1000,
#  'option_compute_btable': 0,
#  'option_compute_ktable': 0,
#  'option_wgt_flux': 1,
#  'option_wgt_k': 1,
#  'ref_pts': [(1, 250), (10, 250), (500, 250)],
#  'tsfc': 294,
#  'vmax': 620,
#  'vmin': 540,
#  'w_diffuse': [(1.6, 1.6, 1.7), (1.75, 1.75), (1.55, 1.55, 1.6, 1.85)],
#  'wgt': [(0.7, 0.3, 0.7), (0.7, 0.6), (0.4, 0.5, 0.8, 0.95)]}
#
# {'atmpro': 'saw',
#  'band': '3a',
#  'commitnumber': 'a06b618_testbsub',
#  'conc': 0.0004,
#  'dv': 0.001,
#  'klin': 6.375563e-24,
#  'molecule': 'co2',
#  'ng_adju': [0, 0, 0],
#  'ng_refs': [3, 2, 4],
#  'nv': 1000,
#  'option_compute_btable': 0,
#  'option_compute_ktable': 0,
#  'option_wgt_flux': 1,
#  'option_wgt_k': 1,
#  'ref_pts': [(1, 250), (10, 250), (500, 250)],
#  'tsfc': 257,
#  'vmax': 620,
#  'vmin': 540,
#  'w_diffuse': [(1.6, 1.6, 1.7), (1.75, 1.75), (1.55, 1.55, 1.6, 1.85)],
#  'wgt': [(0.7, 0.3, 0.7), (0.7, 0.6), (0.4, 0.5, 0.8, 0.95)]}
#
# {'atmpro': 'trp',
#  'band': '3a',
#  'commitnumber': 'a06b618_testbsub',
#  'conc': 0.0004,
#  'dv': 0.001,
#  'klin': 6.375563e-24,
#  'molecule': 'co2',
#  'ng_adju': [0, 0, 0],
#  'ng_refs': [3, 2, 4],
#  'nv': 1000,
#  'option_compute_btable': 0,
#  'option_compute_ktable': 0,
#  'option_wgt_flux': 1,
#  'option_wgt_k': 1,
#  'ref_pts': [(1, 250), (10, 250), (500, 250)],
#  'tsfc': 300,
#  'vmax': 620,
#  'vmin': 540,
#  'w_diffuse': [(1.6, 1.6, 1.7), (1.75, 1.75), (1.55, 1.55, 1.6, 1.85)],
#  'wgt': [(0.7, 0.3, 0.7), (0.7, 0.6), (0.4, 0.5, 0.8, 0.95)]}
#
# {'atmpro': 'mls',
#  'band': '3a',
#  'commitnumber': 'a06b618_testbsub',
#  'conc': 3.2e-07,
#  'dv': 0.001,
#  'klin': 2.22e-20,
#  'molecule': 'n2o',
#  'ng_adju': [0, 0],
#  'ng_refs': [1, 2],
#  'nv': 1000,
#  'option_compute_btable': 0,
#  'option_compute_ktable': 0,
#  'option_wgt_flux': 1,
#  'option_wgt_k': 1,
#  'ref_pts': [(1, 250), (500, 250)],
#  'tsfc': 294,
#  'vmax': 620,
#  'vmin': 540,
#  'w_diffuse': [(1.8,), (1.66, 1.8)],
#  'wgt': [(0.9,), (0.5, 0.95)]}
#
# {'atmpro': 'saw',
#  'band': '3a',
#  'commitnumber': 'a06b618_testbsub',
#  'conc': 3.2e-07,
#  'dv': 0.001,
#  'klin': 2.22e-20,
#  'molecule': 'n2o',
#  'ng_adju': [0, 0],
#  'ng_refs': [1, 2],
#  'nv': 1000,
#  'option_compute_btable': 0,
#  'option_compute_ktable': 0,
#  'option_wgt_flux': 1,
#  'option_wgt_k': 1,
#  'ref_pts': [(1, 250), (500, 250)],
#  'tsfc': 257,
#  'vmax': 620,
#  'vmin': 540,
#  'w_diffuse': [(1.8,), (1.66, 1.8)],
#  'wgt': [(0.9,), (0.5, 0.95)]}
#
# {'atmpro': 'trp',
#  'band': '3a',
#  'commitnumber': 'a06b618_testbsub',
#  'conc': 3.2e-07,
#  'dv': 0.001,
#  'klin': 2.22e-20,
#  'molecule': 'n2o',
#  'ng_adju': [0, 0],
#  'ng_refs': [1, 2],
#  'nv': 1000,
#  'option_compute_btable': 0,
#  'option_compute_ktable': 0,
#  'option_wgt_flux': 1,
#  'option_wgt_k': 1,
#  'ref_pts': [(1, 250), (500, 250)],
#  'tsfc': 300,
#  'vmax': 620,
#  'vmin': 540,
#  'w_diffuse': [(1.8,), (1.66, 1.8)],
#  'wgt': [(0.9,), (0.5, 0.95)]}
#
# {'atmpro': 'trp',
#  'band': '3a',
#  'commitnumber': 'a06b618_testbsub',
#  'conc': 3.2e-07,
#  'dv': 0.001,
#  'klin': 2.22e-20,
#  'molecule': 'n2o',
#  'ng_adju': [0, 0],
#  'ng_refs': [1, 2],
#  'nv': 1000,
#  'option_compute_btable': 0,
#  'option_compute_ktable': 0,
#  'option_wgt_flux': 1,
#  'option_wgt_k': 1,
#  'ref_pts': [(1, 250), (500, 250)],
#  'tsfc': 300,
#  'vmax': 620,
#  'vmin': 540,
#  'w_diffuse': [(1.8,), (1.66, 1.8)],
#  'wgt': [(0.9,), (0.5, 0.95)]}
# {'atmpro': 'trp',
#  'band': '3a',
#  'commitnumber': 'a06b618_testbsub',
#  'conc': 3.2e-07,
#  'dv': 0.001,
#  'klin': 2.22e-20,
#  'molecule': 'n2o',
#  'ng_adju': [0, 0],
#  'ng_refs': [1, 2],
#  'nv': 1000,
#  'option_compute_btable': 0,
#  'option_compute_ktable': 0,
#  'option_wgt_flux': 1,
#  'option_wgt_k': 1,
#  'ref_pts': [(1, 250), (500, 250)],
#  'tsfc': 300,
#  'vmax': 620,
#  'vmin': 540,
#  'w_diffuse': [(1.8,), (1.66, 1.8)],
#  'wgt': [(0.9,), (0.5, 0.95)]}
# {'atmpro': 'mls',
#  'band': '3a',
#  'commitnumber': 'a06b618_testbsub',
#  'conc': 3.2e-07,
#  'dv': 0.001,
#  'klin': 2.22e-20,
#  'molecule': 'n2o',
#  'ng_adju': [0, 0],
#  'ng_refs': [1, 2],
#  'nv': 1000,
#  'option_compute_btable': 0,
#  'option_compute_ktable': 0,
#  'option_wgt_flux': 1,
#  'option_wgt_k': 1,
#  'ref_pts': [(1, 250), (500, 250)],
#  'tsfc': 294,
#  'vmax': 620,
#  'vmin': 540,
#  'w_diffuse': [(1.8,), (1.66, 1.8)],
#  'wgt': [(0.9,), (0.5, 0.95)]}
# {'atmpro': 'saw',
#  'band': '3a',
#  'commitnumber': 'a06b618_testbsub',
#  'conc': 3.2e-07,
#  'dv': 0.001,
#  'klin': 2.22e-20,
#  'molecule': 'n2o',
#  'ng_adju': [0, 0],
#  'ng_refs': [1, 2],
#  'nv': 1000,
#  'option_compute_btable': 0,
#  'option_compute_ktable': 0,
#  'option_wgt_flux': 1,
#  'option_wgt_k': 1,
#  'ref_pts': [(1, 250), (500, 250)],
#  'tsfc': 257,
#  'vmax': 620,
#  'vmin': 540,
#  'w_diffuse': [(1.8,), (1.66, 1.8)],
#  'wgt': [(0.9,), (0.5, 0.95)]}
# {'atmpro': 'trp',
#  'band': '3a',
#  'commitnumber': 'a06b618_testbsub',
#  'conc': 3.2e-07,
#  'dv': 0.001,
#  'klin': 2.22e-20,
#  'molecule': 'n2o',
#  'ng_adju': [0, 0],
#  'ng_refs': [1, 2],
#  'nv': 1000,
#  'option_compute_btable': 0,
#  'option_compute_ktable': 0,
#  'option_wgt_flux': 1,
#  'option_wgt_k': 1,
#  'ref_pts': [(1, 250), (500, 250)],
#  'tsfc': 300,
#  'vmax': 620,
#  'vmin': 540,
#  'w_diffuse': [(1.8,), (1.66, 1.8)],
#  'wgt': [(0.9,), (0.5, 0.95)]}
# {'atmpro': 'mls',
#  'band': '3a',
#  'commitnumber': 'a06b618_testbsub',
#  'conc': None,
#  'dv': 0.001,
#  'klin': 0,
#  'molecule': 'h2o',
#  'ng_adju': [0, 0],
#  'ng_refs': [2, 6],
#  'nv': 1000,
#  'option_compute_btable': 0,
#  'option_compute_ktable': 0,
#  'option_wgt_flux': 1,
#  'option_wgt_k': 1,
#  'ref_pts': [(10, 250), (600, 250)],
#  'tsfc': 294,
#  'vmax': 620,
#  'vmin': 540,
#  'w_diffuse': [(1.9, 1.7), (1.4, 1.4, 1.4, 1.55, 1.6, 1.66)],
#  'wgt': [(0.7, 0.7), (0.7, 0.5, 0.5, 0.5, 0.5, 0.5)]}
# {'atmpro': 'trp',
#  'band': '3a',
#  'commitnumber': 'a06b618_testbsub',
#  'conc': None,
#  'dv': 0.001,
#  'klin': 0,
#  'molecule': 'h2o',
#  'ng_adju': [0, 0],
#  'ng_refs': [2, 6],
#  'nv': 1000,
#  'option_compute_btable': 0,
#  'option_compute_ktable': 0,
#  'option_wgt_flux': 1,
#  'option_wgt_k': 1,
#  'ref_pts': [(10, 250), (600, 250)],
#  'tsfc': 300,
#  'vmax': 620,
#  'vmin': 540,
#  'w_diffuse': [(1.9, 1.7), (1.4, 1.4, 1.4, 1.55, 1.6, 1.66)],
#  'wgt': [(0.7, 0.7), (0.7, 0.5, 0.5, 0.5, 0.5, 0.5)]}
# {'atmpro': 'mls',
#  'band': '3a',
#  'commitnumber': 'a06b618_testbsub',
#  'conc': 0.0004,
#  'dv': 0.001,
#  'klin': 6.375563e-24,
#  'molecule': 'co2',
#  'ng_adju': [0, 0, 0],
#  'ng_refs': [3, 2, 4],
#  'nv': 1000,
#  'option_compute_btable': 0,
#  'option_compute_ktable': 0,
#  'option_wgt_flux': 1,
#  'option_wgt_k': 1,
#  'ref_pts': [(1, 250), (10, 250), (500, 250)],
#  'tsfc': 294,
#  'vmax': 620,
#  'vmin': 540,
#  'w_diffuse': [(1.6, 1.6, 1.7), (1.75, 1.75), (1.55, 1.55, 1.6, 1.85)],
#  'wgt': [(0.7, 0.3, 0.7), (0.7, 0.6), (0.4, 0.5, 0.8, 0.95)]}
# {'atmpro': 'saw',
#  'band': '3a',
#  'commitnumber': 'a06b618_testbsub',
#  'conc': 0.0004,
#  'dv': 0.001,
#  'klin': 6.375563e-24,
#  'molecule': 'co2',
#  'ng_adju': [0, 0, 0],
#  'ng_refs': [3, 2, 4],
#  'nv': 1000,
#  'option_compute_btable': 0,
#  'option_compute_ktable': 0,
#  'option_wgt_flux': 1,
#  'option_wgt_k': 1,
#  'ref_pts': [(1, 250), (10, 250), (500, 250)],
#  'tsfc': 257,
#  'vmax': 620,
#  'vmin': 540,
#  'w_diffuse': [(1.6, 1.6, 1.7), (1.75, 1.75), (1.55, 1.55, 1.6, 1.85)],
#  'wgt': [(0.7, 0.3, 0.7), (0.7, 0.6), (0.4, 0.5, 0.8, 0.95)]}
# {'atmpro': 'trp',
#  'band': '3a',
#  'commitnumber': 'a06b618_testbsub',
#  'conc': 0.0004,
#  'dv': 0.001,
#  'klin': 6.375563e-24,
#  'molecule': 'co2',
#  'ng_adju': [0, 0, 0],
#  'ng_refs': [3, 2, 4],
#  'nv': 1000,
#  'option_compute_btable': 0,
#  'option_compute_ktable': 0,
#  'option_wgt_flux': 1,
#  'option_wgt_k': 1,
#  'ref_pts': [(1, 250), (10, 250), (500, 250)],
#  'tsfc': 300,
#  'vmax': 620,
#  'vmin': 540,
#  'w_diffuse': [(1.6, 1.6, 1.7), (1.75, 1.75), (1.55, 1.55, 1.6, 1.85)],
#  'wgt': [(0.7, 0.3, 0.7), (0.7, 0.6), (0.4, 0.5, 0.8, 0.95)]}
# {'atmpro': 'mls',
#  'band': '3a',
#  'commitnumber': 'a06b618_testbsub',
#  'conc': 3.2e-07,
#  'dv': 0.001,
#  'klin': 2.22e-20,
#  'molecule': 'n2o',
#  'ng_adju': [0, 0],
#  'ng_refs': [1, 2],
#  'nv': 1000,
#  'option_compute_btable': 0,
#  'option_compute_ktable': 0,
#  'option_wgt_flux': 1,
#  'option_wgt_k': 1,
#  'ref_pts': [(1, 250), (500, 250)],
#  'tsfc': 294,
#  'vmax': 620,
#  'vmin': 540,
#  'w_diffuse': [(1.8,), (1.66, 1.8)],
#  'wgt': [(0.9,), (0.5, 0.95)]}
# {'atmpro': 'saw',
#  'band': '3a',
#  'commitnumber': 'a06b618_testbsub',
#  'conc': 3.2e-07,
#  'dv': 0.001,
#  'klin': 2.22e-20,
#  'molecule': 'n2o',
#  'ng_adju': [0, 0],
#  'ng_refs': [1, 2],
#  'nv': 1000,
#  'option_compute_btable': 0,
#  'option_compute_ktable': 0,
#  'option_wgt_flux': 1,
#  'option_wgt_k': 1,
#  'ref_pts': [(1, 250), (500, 250)],
#  'tsfc': 257,
#  'vmax': 620,
#  'vmin': 540,
#  'w_diffuse': [(1.8,), (1.66, 1.8)],
#  'wgt': [(0.9,), (0.5, 0.95)]}
# {'atmpro': 'trp',
#  'band': '3a',
#  'commitnumber': 'a06b618_testbsub',
#  'conc': 3.2e-07,
#  'dv': 0.001,
#  'klin': 2.22e-20,
#  'molecule': 'n2o',
#  'ng_adju': [0, 0],
#  'ng_refs': [1, 2],
#  'nv': 1000,
#  'option_compute_btable': 0,
#  'option_compute_ktable': 0,
#  'option_wgt_flux': 1,
#  'option_wgt_k': 1,
#  'ref_pts': [(1, 250), (500, 250)],
#  'tsfc': 300,
#  'vmax': 620,
#  'vmin': 540,
#  'w_diffuse': [(1.8,), (1.66, 1.8)],
#  'wgt': [(0.9,), (0.5, 0.95)]}
# {'atmpro': 'mls',
#  'band': '3a',
#  'commitnumber': 'a06b618_testbsub',
#  'conc': None,
#  'dv': 0.001,
#  'klin': 0,
#  'molecule': 'h2o',
#  'ng_adju': [0, 0],
#  'ng_refs': [2, 6],
#  'nv': 1000,
#  'option_compute_btable': 0,
#  'option_compute_ktable': 0,
#  'option_wgt_flux': 1,
#  'option_wgt_k': 1,
#  'ref_pts': [(10, 250), (600, 250)],
#  'tsfc': 294,
#  'vmax': 620,
#  'vmin': 540,
#  'w_diffuse': [(1.9, 1.7), (1.4, 1.4, 1.4, 1.55, 1.6, 1.66)],
#  'wgt': [(0.7, 0.7), (0.7, 0.5, 0.5, 0.5, 0.5, 0.5)]}
# {'atmpro': 'saw',
#  'band': '3a',
#  'commitnumber': 'a06b618_testbsub',
#  'conc': None,
#  'dv': 0.001,
#  'klin': 0,
#  'molecule': 'h2o',
#  'ng_adju': [0, 0],
#  'ng_refs': [2, 6],
#  'nv': 1000,
#  'option_compute_btable': 0,
#  'option_compute_ktable': 0,
#  'option_wgt_flux': 1,
#  'option_wgt_k': 1,
#  'ref_pts': [(10, 250), (600, 250)],
#  'tsfc': 257,
#  'vmax': 620,
#  'vmin': 540,
#  'w_diffuse': [(1.9, 1.7), (1.4, 1.4, 1.4, 1.55, 1.6, 1.66)],
#  'wgt': [(0.7, 0.7), (0.7, 0.5, 0.5, 0.5, 0.5, 0.5)]}
# {'atmpro': 'trp',
#  'band': '3a',
#  'commitnumber': 'a06b618_testbsub',
#  'conc': None,
#  'dv': 0.001,
#  'klin': 0,
#  'molecule': 'h2o',
#  'ng_adju': [0, 0],
#  'ng_refs': [2, 6],
#  'nv': 1000,
#  'option_compute_btable': 0,
#  'option_compute_ktable': 0,
#  'option_wgt_flux': 1,
#  'option_wgt_k': 1,
#  'ref_pts': [(10, 250), (600, 250)],
#  'tsfc': 300,
#  'vmax': 620,
#  'vmin': 540,
#  'w_diffuse': [(1.9, 1.7), (1.4, 1.4, 1.4, 1.55, 1.6, 1.66)],
#  'wgt': [(0.7, 0.7), (0.7, 0.5, 0.5, 0.5, 0.5, 0.5)]}
# {'atmpro': 'mls',
#  'band': '3a',
#  'commitnumber': 'a06b618_testbsub',
#  'conc': 0.0004,
#  'dv': 0.001,
#  'klin': 6.375563e-24,
#  'molecule': 'co2',
#  'ng_adju': [0, 0, 0],
#  'ng_refs': [3, 2, 4],
#  'nv': 1000,
#  'option_compute_btable': 0,
#  'option_compute_ktable': 0,
#  'option_wgt_flux': 1,
#  'option_wgt_k': 1,
#  'ref_pts': [(1, 250), (10, 250), (500, 250)],
#  'tsfc': 294,
#  'vmax': 620,
#  'vmin': 540,
#  'w_diffuse': [(1.6, 1.6, 1.7), (1.75, 1.75), (1.55, 1.55, 1.6, 1.85)],
#  'wgt': [(0.7, 0.3, 0.7), (0.7, 0.6), (0.4, 0.5, 0.8, 0.95)]}
# {'atmpro': 'saw',
#  'band': '3a',
#  'commitnumber': 'a06b618_testbsub',
#  'conc': 0.0004,
#  'dv': 0.001,
#  'klin': 6.375563e-24,
#  'molecule': 'co2',
#  'ng_adju': [0, 0, 0],
#  'ng_refs': [3, 2, 4],
#  'nv': 1000,
#  'option_compute_btable': 0,
#  'option_compute_ktable': 0,
#  'option_wgt_flux': 1,
#  'option_wgt_k': 1,
#  'ref_pts': [(1, 250), (10, 250), (500, 250)],
#  'tsfc': 257,
#  'vmax': 620,
#  'vmin': 540,
#  'w_diffuse': [(1.6, 1.6, 1.7), (1.75, 1.75), (1.55, 1.55, 1.6, 1.85)],
#  'wgt': [(0.7, 0.3, 0.7), (0.7, 0.6), (0.4, 0.5, 0.8, 0.95)]}
# {'atmpro': 'trp',
#  'band': '3a',
#  'commitnumber': 'a06b618_testbsub',
#  'conc': 0.0004,
#  'dv': 0.001,
#  'klin': 6.375563e-24,
#  'molecule': 'co2',
#  'ng_adju': [0, 0, 0],
#  'ng_refs': [3, 2, 4],
#  'nv': 1000,
#  'option_compute_btable': 0,
#  'option_compute_ktable': 0,
#  'option_wgt_flux': 1,
#  'option_wgt_k': 1,
#  'ref_pts': [(1, 250), (10, 250), (500, 250)],
#  'tsfc': 300,
#  'vmax': 620,
#  'vmin': 540,
#  'w_diffuse': [(1.6, 1.6, 1.7), (1.75, 1.75), (1.55, 1.55, 1.6, 1.85)],
#  'wgt': [(0.7, 0.3, 0.7), (0.7, 0.6), (0.4, 0.5, 0.8, 0.95)]}
# {'atmpro': 'mls',
#  'band': '3a',
#  'commitnumber': 'a06b618_testbsub',
#  'conc': 3.2e-07,
#  'dv': 0.001,
#  'klin': 2.22e-20,
#  'molecule': 'n2o',
#  'ng_adju': [0, 0],
#  'ng_refs': [1, 2],
#  'nv': 1000,
#  'option_compute_btable': 0,
#  'option_compute_ktable': 0,
#  'option_wgt_flux': 1,
#  'option_wgt_k': 1,
#  'ref_pts': [(1, 250), (500, 250)],
#  'tsfc': 294,
#  'vmax': 620,
#  'vmin': 540,
#  'w_diffuse': [(1.8,), (1.66, 1.8)],
#  'wgt': [(0.9,), (0.5, 0.95)]}
# {'atmpro': 'saw',
#  'band': '3a',
#  'commitnumber': 'a06b618_testbsub',
#  'conc': 3.2e-07,
#  'dv': 0.001,
#  'klin': 2.22e-20,
#  'molecule': 'n2o',
#  'ng_adju': [0, 0],
#  'ng_refs': [1, 2],
#  'nv': 1000,
#  'option_compute_btable': 0,
#  'option_compute_ktable': 0,
#  'option_wgt_flux': 1,
#  'option_wgt_k': 1,
#  'ref_pts': [(1, 250), (500, 250)],
#  'tsfc': 257,
#  'vmax': 620,
#  'vmin': 540,
#  'w_diffuse': [(1.8,), (1.66, 1.8)],
#  'wgt': [(0.9,), (0.5, 0.95)]}
# {'atmpro': 'trp',
#  'band': '3a',
#  'commitnumber': 'a06b618_testbsub',
#  'conc': 3.2e-07,
#  'dv': 0.001,
#  'klin': 2.22e-20,
#  'molecule': 'n2o',
#  'ng_adju': [0, 0],
#  'ng_refs': [1, 2],
#  'nv': 1000,
#  'option_compute_btable': 0,
#  'option_compute_ktable': 0,
#  'option_wgt_flux': 1,
#  'option_wgt_k': 1,
#  'ref_pts': [(1, 250), (500, 250)],
#  'tsfc': 300,
#  'vmax': 620,
#  'vmin': 540,
#  'w_diffuse': [(1.8,), (1.66, 1.8)],
#  'wgt': [(0.9,), (0.5, 0.95)]}

# %%
for param in params:
    print(param['molecule'], 'band', param['band'], param['atmpro'])
    print(pipeline.nbviewer_url(param=param, setup=setup_bestfit))
    print()
# Out:
# h2o band 3a mls
# http://nbviewer.jupyter.org/github/qap/offline_radiation_notebooks/blob/master/longwave/lblnew_20160916/study__g1_threshold/h2o/conc_None/band03a_wn_540_620/nv_1000/dv_0.001/ng_8/g_ascending_k_descending/refPTs_P_10_T_250__P_600_T_250/ng_refs_2__6/ng_adju_0__0/getabsth_auto__auto/absth_dlogN_uniform__dlogN_uniform/klin_none/atmpro_mls/wgt_k_1/wgt_0.7_0.7__0.7_0.5_0.5_0.5_0.5_0.5/wgt_flux_1/w_diffuse_1.9_1.7__1.4_1.4_1.4_1.55_1.6_1.66/option_compute_ktable_0/option_compute_btable_0/crd_a06b618_testbsub/results.ipynb
#
# h2o band 3a saw
# http://nbviewer.jupyter.org/github/qap/offline_radiation_notebooks/blob/master/longwave/lblnew_20160916/study__g1_threshold/h2o/conc_None/band03a_wn_540_620/nv_1000/dv_0.001/ng_8/g_ascending_k_descending/refPTs_P_10_T_250__P_600_T_250/ng_refs_2__6/ng_adju_0__0/getabsth_auto__auto/absth_dlogN_uniform__dlogN_uniform/klin_none/atmpro_saw/wgt_k_1/wgt_0.7_0.7__0.7_0.5_0.5_0.5_0.5_0.5/wgt_flux_1/w_diffuse_1.9_1.7__1.4_1.4_1.4_1.55_1.6_1.66/option_compute_ktable_0/option_compute_btable_0/crd_a06b618_testbsub/results.ipynb
#
# h2o band 3a trp
# http://nbviewer.jupyter.org/github/qap/offline_radiation_notebooks/blob/master/longwave/lblnew_20160916/study__g1_threshold/h2o/conc_None/band03a_wn_540_620/nv_1000/dv_0.001/ng_8/g_ascending_k_descending/refPTs_P_10_T_250__P_600_T_250/ng_refs_2__6/ng_adju_0__0/getabsth_auto__auto/absth_dlogN_uniform__dlogN_uniform/klin_none/atmpro_trp/wgt_k_1/wgt_0.7_0.7__0.7_0.5_0.5_0.5_0.5_0.5/wgt_flux_1/w_diffuse_1.9_1.7__1.4_1.4_1.4_1.55_1.6_1.66/option_compute_ktable_0/option_compute_btable_0/crd_a06b618_testbsub/results.ipynb
#
# co2 band 3a mls
# http://nbviewer.jupyter.org/github/qap/offline_radiation_notebooks/blob/master/longwave/lblnew_20160916/study__g1_threshold/co2/conc_0.0004/band03a_wn_540_620/nv_1000/dv_0.001/ng_9/g_ascending_k_descending/refPTs_P_1_T_250__P_10_T_250__P_500_T_250/ng_refs_3__2__4/ng_adju_0__0__0/getabsth_auto__auto__auto/absth_dlogN_uniform__dlogN_uniform__dlogN_uniform/klin_6.375563e-24/atmpro_mls/wgt_k_1/wgt_0.7_0.3_0.7__0.7_0.6__0.4_0.5_0.8_0.95/wgt_flux_1/w_diffuse_1.6_1.6_1.7__1.75_1.75__1.55_1.55_1.6_1.85/option_compute_ktable_0/option_compute_btable_0/crd_a06b618_testbsub/results.ipynb
#
# co2 band 3a saw
# http://nbviewer.jupyter.org/github/qap/offline_radiation_notebooks/blob/master/longwave/lblnew_20160916/study__g1_threshold/co2/conc_0.0004/band03a_wn_540_620/nv_1000/dv_0.001/ng_9/g_ascending_k_descending/refPTs_P_1_T_250__P_10_T_250__P_500_T_250/ng_refs_3__2__4/ng_adju_0__0__0/getabsth_auto__auto__auto/absth_dlogN_uniform__dlogN_uniform__dlogN_uniform/klin_6.375563e-24/atmpro_saw/wgt_k_1/wgt_0.7_0.3_0.7__0.7_0.6__0.4_0.5_0.8_0.95/wgt_flux_1/w_diffuse_1.6_1.6_1.7__1.75_1.75__1.55_1.55_1.6_1.85/option_compute_ktable_0/option_compute_btable_0/crd_a06b618_testbsub/results.ipynb
#
# co2 band 3a trp
# http://nbviewer.jupyter.org/github/qap/offline_radiation_notebooks/blob/master/longwave/lblnew_20160916/study__g1_threshold/co2/conc_0.0004/band03a_wn_540_620/nv_1000/dv_0.001/ng_9/g_ascending_k_descending/refPTs_P_1_T_250__P_10_T_250__P_500_T_250/ng_refs_3__2__4/ng_adju_0__0__0/getabsth_auto__auto__auto/absth_dlogN_uniform__dlogN_uniform__dlogN_uniform/klin_6.375563e-24/atmpro_trp/wgt_k_1/wgt_0.7_0.3_0.7__0.7_0.6__0.4_0.5_0.8_0.95/wgt_flux_1/w_diffuse_1.6_1.6_1.7__1.75_1.75__1.55_1.55_1.6_1.85/option_compute_ktable_0/option_compute_btable_0/crd_a06b618_testbsub/results.ipynb
#
# n2o band 3a mls
# http://nbviewer.jupyter.org/github/qap/offline_radiation_notebooks/blob/master/longwave/lblnew_20160916/study__g1_threshold/n2o/conc_3.2e-07/band03a_wn_540_620/nv_1000/dv_0.001/ng_3/g_ascending_k_descending/refPTs_P_1_T_250__P_500_T_250/ng_refs_1__2/ng_adju_0__0/getabsth_auto__auto/absth_dlogN_uniform__dlogN_uniform/klin_2.22e-20/atmpro_mls/wgt_k_1/wgt_0.9__0.5_0.95/wgt_flux_1/w_diffuse_1.8__1.66_1.8/option_compute_ktable_0/option_compute_btable_0/crd_a06b618_testbsub/results.ipynb
#
# n2o band 3a saw
# http://nbviewer.jupyter.org/github/qap/offline_radiation_notebooks/blob/master/longwave/lblnew_20160916/study__g1_threshold/n2o/conc_3.2e-07/band03a_wn_540_620/nv_1000/dv_0.001/ng_3/g_ascending_k_descending/refPTs_P_1_T_250__P_500_T_250/ng_refs_1__2/ng_adju_0__0/getabsth_auto__auto/absth_dlogN_uniform__dlogN_uniform/klin_2.22e-20/atmpro_saw/wgt_k_1/wgt_0.9__0.5_0.95/wgt_flux_1/w_diffuse_1.8__1.66_1.8/option_compute_ktable_0/option_compute_btable_0/crd_a06b618_testbsub/results.ipynb
#
# n2o band 3a trp
# http://nbviewer.jupyter.org/github/qap/offline_radiation_notebooks/blob/master/longwave/lblnew_20160916/study__g1_threshold/n2o/conc_3.2e-07/band03a_wn_540_620/nv_1000/dv_0.001/ng_3/g_ascending_k_descending/refPTs_P_1_T_250__P_500_T_250/ng_refs_1__2/ng_adju_0__0/getabsth_auto__auto/absth_dlogN_uniform__dlogN_uniform/klin_2.22e-20/atmpro_trp/wgt_k_1/wgt_0.9__0.5_0.95/wgt_flux_1/w_diffuse_1.8__1.66_1.8/option_compute_ktable_0/option_compute_btable_0/crd_a06b618_testbsub/results.ipynb
