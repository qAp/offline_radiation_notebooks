# %%
# %matplotlib inline
import os
import re

import matplotlib
import numpy as np
import pandas as pd
import xarray as xr

import climatools.html.html as climahtml
import climatools.scripts.g1_threshold as scripts

import IPython.display as display

import imp
imp.reload(scripts)
# Out:
# /nuwa_cluster/home/jackyu/locally_installed_python_pacakges/anaconda3/lib/python3.4/site-packages/matplotlib/__init__.py:1401: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# <module 'climatools.scripts.g1_threshold' from '/nuwa_cluster/home/jackyu/climatools/climatools/scripts/g1_threshold.py'>

# %%
# for printing some input parameters

def innames():
    return ['vstar', 'nband', 'nv', 'dv',
            'tsfc',
            'pressure_reference_1',
            'temperature_reference_1', 
            'pressure_reference_2', 
            'temperature_reference_2',
            'ighigh', 
            'ng', 
            'nref',
            'p_refs',
            't_refs',
            'ng_refs',
            'absth',
            'wgt',
            'planck_wgt_flux',
            'fac_meank']


def pattern_assign(name):
    return ''' 
    parameter .* :: \s* &? \s* ({} \s* = .* \n)
    '''.format(name)

def pattern_data(name):
    return '''
    (data [^/{name}]+ {name}[^,] [^/{name}]+ / [^/]+ /)
    '''.format(name=name)

def pattern_atmpro():
    return '''
    (include \s+ '.*\.pro')
    '''


def get_input_params(code, names):
    results = []
    for name in names:
        regex = re.compile(pattern_assign(name), re.VERBOSE)
        results.extend(regex.findall(code))
        
        regex = re.compile(pattern_data(name), re.VERBOSE)
        results.extend(regex.findall(code))
        
    regex = re.compile(pattern_atmpro(), re.VERBOSE)
    results.extend(regex.findall(code))
        
    results = [result.replace('_r8', '') for result in results]
    return results

# %%
analysis = scripts.Analysis()

# %%
crd = analysis.model('crd')
crd.type_model = 'crd'
crd.rundir = os.path.join('/nuwa_cluster/home/jackyu/radiation/crd',
                          'LW/examples/separate_g_groups',
                          'study__lblnew_g1_threshold',
                          'h2o',
                          'band01_wn_10_340',
                          'ng_10',
                          'g_descending',
                          'refPTs_P_1_T_250__P_30_T_250__P_300_T_250',
                          'ng_refs_3__2__5',
                          'getabsth_auto__auto__auto',
                          'absth_dlogN_uniform__dlogN_uniform__dlogN_uniform',
                          'wgt_all.65__all.7__.7_.8_.65_.65_.65',
                          'bigsum',
                          'mdc_0501_63cd4cc',
                          'atmpro_trp')
crd.fpath_flux = 'output_fluxg.dat'
crd.fpath_coolr = 'output_coolrg.dat'
crd.linestyle = '-'
crd.load_data()

# %%
crdx_wgt = analysis.model('wgt')
crdx_wgt.type_model = 'crd'
crdx_wgt.rundir = os.path.join('/nuwa_cluster/home/jackyu/radiation/crd',
                          'LW/examples/separate_g_groups',
                          'study__lblnew_g1_threshold',
                          'h2o',
                          'band01_wn_10_340',
                          'ng_10',
                          'g_descending',
                          'refPTs_P_1_T_250__P_30_T_250__P_300_T_250',
                          'ng_refs_3__2__5',
                          'getabsth_auto__auto__auto',
                          'absth_dlogN_uniform__dlogN_uniform__dlogN_uniform',
                          'wgt_all.65__all.7__.7_.8_.65_.65_.65',
                          'bigsum',
                          'mdc_0501_63cd4cc',
                          'atmpro_trp')
crdx_wgt.fpath_flux = 'output_xfluxg.dat'
crdx_wgt.fpath_coolr = 'output_xcoolrg.dat'
crdx_wgt.linestyle = '--'
crdx_wgt.load_data()

# %%
fig = analysis.fig_fluxcoolr('fig1')
fig.ggroups = list(range(1, 10 + 1))
fig.vars_plot['flux'] = ['flug', 'fnetg']
fig.vars_plot['cooling rate'] = ['coolrg']
fig.colors['flug'] = 'darkred'
fig.colors['fnetg'] = 'lightcoral'
fig.colors['coolrg'] = 'blue'
fig.varlims_from_indexrange['linear'] = (50, 1050)
fig.varlims_from_indexrange['log'] = (1e-4, 50)

# %%
table_fluxg = analysis.table('table_fluxg')
table_fluxg.sumg = False
table_fluxg.vartype = 'flux'
table_fluxg.at_pressures = crd.data['flux']\
                             .coords['pressure']\
                             .isel(pressure=[0, -1])

table_coolrg = analysis.table('table_coolrg')
table_coolrg.vartype = 'cooling rate'
table_coolrg.sumg = False
table_coolrg.at_pressures = crd.data['cooling rate']\
                               .coords['pressure']\
                               .isel(pressure=[0, -1])

# %%
table_flux = analysis.table('table_flux')
table_flux.sumg = True
table_flux.vartype = 'flux'
table_flux.at_pressures = crd.data['flux']\
                             .coords['pressure']\
                             .isel(pressure=[0, -1])

table_coolr = analysis.table('table_coolr')
table_coolr.vartype = 'cooling rate'
table_coolr.sumg = True
table_coolr.at_pressures = crd.data['cooling rate']\
                              .coords['pressure']\
                              .isel(pressure=[0, -1])

# %%
table_dgdgs = analysis.table('dgdgs')
table_dgdgs.vartype = 'dgdgs'
table_dgdgs.sumg = False

# %%
# print some input parameters

with open(os.path.join(crd.rundir, 'lblnew.f'), 
          mode='r', encoding='utf-8') as f:
    c = f.read()

print('\n\n'.join(get_input_params(c, innames())))
# Out:
# vstar = 10
#
# nband = 330
#
# nv = 200
#
# dv = 0.005
#
# tsfc = 300.0
#
# ng = 10
#
# nref = 3
#
# p_refs = (/ 1,  30, 300 /)
#
# t_refs = (/ 250, 250, 250 /)
#
# ng_refs = (/ 3,   2,   5 /)
#
# data wgt
#      &     /3*.65, .8, .7,
#      &     2*.7,
#      &     3*.65/
#
# planck_wgt_flux = 2
#
# include 'trp75.pro'

# %%
fig.display_hrefanchor()
# Out:
# <a href="#Figure:_flux,_cooling_rate._g-group_1">Figure: flux, cooling rate. g-group 1</a>
# <a href="#Figure:_flux,_cooling_rate._g-group_2">Figure: flux, cooling rate. g-group 2</a>
# <a href="#Figure:_flux,_cooling_rate._g-group_3">Figure: flux, cooling rate. g-group 3</a>
# <a href="#Figure:_flux,_cooling_rate._g-group_4">Figure: flux, cooling rate. g-group 4</a>
# <a href="#Figure:_flux,_cooling_rate._g-group_5">Figure: flux, cooling rate. g-group 5</a>
# <a href="#Figure:_flux,_cooling_rate._g-group_6">Figure: flux, cooling rate. g-group 6</a>
# <a href="#Figure:_flux,_cooling_rate._g-group_7">Figure: flux, cooling rate. g-group 7</a>
# <a href="#Figure:_flux,_cooling_rate._g-group_8">Figure: flux, cooling rate. g-group 8</a>
# <a href="#Figure:_flux,_cooling_rate._g-group_9">Figure: flux, cooling rate. g-group 9</a>
# <a href="#Figure:_flux,_cooling_rate._g-group_10">Figure: flux, cooling rate. g-group 10</a>
# <a href="#Figure:_flux,_cooling_rate._g-group_total">Figure: flux, cooling rate. g-group total</a>

# %%
table_fluxg.display_hrefanchor()
table_coolrg.display_hrefanchor()

table_flux.display_hrefanchor()
table_coolr.display_hrefanchor()
# Out:
# <a href="#Table:_flux._g-groups">Table: flux. g-groups </a>
# <a href="#Table:_cooling_rate._g-groups">Table: cooling rate. g-groups </a>
# <a href="#Table:_flux._g-groups_total">Table: flux. g-groups total</a>
# <a href="#Table:_cooling_rate._g-groups_total">Table: cooling rate. g-groups total</a>

# %%
table_dgdgs.display_hrefanchor()
# Out:
# <a href="#Table:_dgdgs._g-groups">Table: dgdgs. g-groups </a>

# %%
s_abscom = 'Overall absth'
display.HTML(climahtml.getHTML_hrefanchor(s_abscom))
# Out:
# <a href="#Overall_absth">Overall absth</a>

# %%
s_ggroup_summary = 'g-group summary'
display.HTML(climahtml.getHTML_hrefanchor(s_ggroup_summary))
# Out:
# <a href="#g-group_summary">g-group summary</a>

# %%
#for g in range(1, 20 + 1):
#    s = 'Table: cooling rate. g-group {}'.format(g)
#    html = climahtml.getHTML_hrefanchor(s)
#    display.display(display.HTML(html))

# %%
matplotlib.rcParams.update({'font.size': 13,
                            'grid.color': 'black',
                            'axes.facecolor': 'white',
                            'axes.edgecolor': 'black',
                            'ytick.direction': 'out',
                            'ytick.major.size': 6, 'ytick.major.width': 1,
                            'ytick.minor.size': 3, 'ytick.minor.width': 1,
                            'xtick.direction': 'out',
                            'xtick.major.size': 6, 'xtick.major.size': 1,
                            'xtick.minor.size': 3, 'xtick.minor.size': 1}) 

fig.plot(analysis)
# Out:
# <a id="Figure:_flux,_cooling_rate._g-group_1"></a>
# # Figure: flux, cooling rate. g-group 1
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# <a id="Figure:_flux,_cooling_rate._g-group_2"></a>
# # Figure: flux, cooling rate. g-group 2
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# <a id="Figure:_flux,_cooling_rate._g-group_3"></a>
# # Figure: flux, cooling rate. g-group 3
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# <a id="Figure:_flux,_cooling_rate._g-group_4"></a>
# # Figure: flux, cooling rate. g-group 4
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# <a id="Figure:_flux,_cooling_rate._g-group_5"></a>
# # Figure: flux, cooling rate. g-group 5
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# <a id="Figure:_flux,_cooling_rate._g-group_6"></a>
# # Figure: flux, cooling rate. g-group 6
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# <a id="Figure:_flux,_cooling_rate._g-group_7"></a>
# # Figure: flux, cooling rate. g-group 7
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# <a id="Figure:_flux,_cooling_rate._g-group_8"></a>
# # Figure: flux, cooling rate. g-group 8
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# <a id="Figure:_flux,_cooling_rate._g-group_9"></a>
# # Figure: flux, cooling rate. g-group 9
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# <a id="Figure:_flux,_cooling_rate._g-group_10"></a>
# # Figure: flux, cooling rate. g-group 10
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# <a id="Figure:_flux,_cooling_rate._g-group_total"></a>
# # Figure: flux, cooling rate. g-group total
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.

# %%
table_fluxg.display_withdiff(analysis, benchmark='crd')
table_coolrg.display_withdiff(analysis, benchmark='crd')
table_flux.display_withdiff(analysis, benchmark='crd')
table_coolr.display_withdiff(analysis, benchmark='crd')
# Out:
# <a id="Table:_flux._g-groups"></a>
# # Table: flux. g-groups
# CRD
#                         flug       fldg      fnetg
# g  pressure level
# 1  0.0      1      -0.015446   0.000000  -0.015446
#    1013.0   76     -0.018056   0.018035  -0.000021
# 2  0.0      1     -13.714025   0.000000 -13.714025
#    1013.0   76    -19.811600  19.802186  -0.009414
# 3  0.0      1     -13.006431   0.000000 -13.006431
#    1013.0   76    -20.019551  20.011040  -0.008511
# 4  0.0      1      -5.394686   0.000000  -5.394686
#    1013.0   76     -9.230948   9.227101  -0.003847
# 5  0.0      1      -1.345314   0.000000  -1.345314
#    1013.0   76     -2.460494   2.459477  -0.001017
# 6  0.0      1      -0.584983   0.000000  -0.584983
#    1013.0   76     -0.945067   0.944674  -0.000393
# 7  0.0      1      -0.180811   0.000000  -0.180811
#    1013.0   76     -0.254208   0.254102  -0.000105
# 8  0.0      1      -0.074697   0.000000  -0.074697
#    1013.0   76     -0.096387   0.096346  -0.000041
# 9  0.0      1      -0.023025   0.000000  -0.023025
#    1013.0   76     -0.032582   0.032568  -0.000014
# 10 0.0      1      -0.007484   0.000000  -0.007484
#    1013.0   76     -0.012998   0.012992  -0.000005
# WGT
#                         flug       fldg      fnetg
# g  pressure level
# 1  0.0      1      -0.015590   0.000000  -0.015590
#    1013.0   76     -0.018056   0.018034  -0.000022
# 2  0.0      1     -13.783202   0.000000 -13.783202
#    1013.0   76    -19.811600  19.802189  -0.009412
# 3  0.0      1     -13.089038   0.000000 -13.089038
#    1013.0   76    -20.019551  20.011040  -0.008511
# 4  0.0      1      -5.349470   0.000000  -5.349470
#    1013.0   76     -9.230948   9.227101  -0.003847
# 5  0.0      1      -1.325221   0.000000  -1.325221
#    1013.0   76     -2.460494   2.459477  -0.001017
# 6  0.0      1      -0.584889   0.000000  -0.584889
#    1013.0   76     -0.945067   0.944674  -0.000393
# 7  0.0      1      -0.180968   0.000000  -0.180968
#    1013.0   76     -0.254208   0.254102  -0.000105
# 8  0.0      1      -0.075164   0.000000  -0.075164
#    1013.0   76     -0.096387   0.096346  -0.000041
# 9  0.0      1      -0.023310   0.000000  -0.023310
#    1013.0   76     -0.032582   0.032568  -0.000014
# 10 0.0      1      -0.007341   0.000000  -0.007341
#    1013.0   76     -0.012998   0.012992  -0.000005
# WGT - CRD
#                        flug      fldg     fnetg
# g  pressure level
# 1  0.0      
CRD
#                             coolrg
# g  pressure    layer
# 1  0.000312    1     -2.515379e-10
#    1001.112500 75     1.030119e-06
# 2  0.000312    1     -3.443090e-05
#    1001.112500 75    -1.580600e-06
# 3  0.000312    1     -4.941694e-04
#    1001.112500 75     0.000000e+00
# 4  0.000312    1     -1.533021e-04
#    1001.112500 75     0.000000e+00
# 5  0.000312    1     -4.753020e-05
#    1001.112500 75     0.000000e+00
# 6  0.000312    1     -8.326670e-05
#    1001.112500 75     0.000000e+00
# 7  0.000312    1     -4.914282e-06
#    1001.112500 75     0.000000e+00
# 8  0.000312    1     -1.130973e-02
#    1001.112500 75     0.000000e+00
# 9  0.000312    1     -1.146611e-01
#    1001.112500 75     0.000000e+00
# 10 0.000312    1     -1.286477e+00
#    1001.112500 75     0.000000e+00
# <a id="Table:_flux._g-groups_total"></a>
# # Table: flux. g-groups total
# CRD
#                      flug       fldg      fnetg
# pressure level
# 0.0      1     -34.346903   0.000000 -34.346903
# 1013.0   76    -52.881891  52.858523  -0.023369
# WGT
#                      flug       fldg      fnetg
# pressure level
# 0.0      1     -34.434193   0.000000 -34.434193
# 1013.0   76    -52.881891  52.858525  -0.023367
# WGT - CRD
#                    flug      fldg     fnetg
# pressure level
# 0.0      1     -0.08729  0.000000 -0.087290
# 1013.0   76     0.00000  0.000002  0.000001
# <a id="Table:_cooling_rate._g-groups_total"></a>
# # Table: cooling rate. g-groups total
# CRD
#                      coolrg
# pressure    layer
# 0.000312    1      4.260222
# 1001.112500 75     0.008415
# WGT
#                      coolrg
# pressure    layer
# 0.000312    1      2.846956
# 1001.112500 75     0.008414
# WGT - CRD
#                          coolrg
# pressure    layer
# 0.000312    1     -1.413266e+00
# 1001.112500 75    -5.504812e-07

# %%
table_dgdgs.display_dgdgs(crd)
# Out:
# <a id="Table:_dgdgs._g-groups"></a>
# # Table: dgdgs. g-groups
#           dg       dgs
# g
# 1   0.020712  0.000390
# 2   0.282879  0.364681
# 3   0.407348  0.383477
# 4   0.204121  0.178004
# 5   0.055864  0.047581
# 6   0.020621  0.018237
# 7   0.005545  0.004909
# 8   0.001985  0.001851
# 9   0.000636  0.000620
# 10  0.000288  0.000249

# %%
# read and display overall absth
display.display(
    display.HTML(climahtml.getHTML_idanchor(s_abscom)))
display.display(
    display.Markdown(climahtml.getMarkdown_sectitle(s_abscom)))

display.display(pd.read_csv(os.path.join(crd.rundir, 'abscom.dat'),
                sep=r'\s+',
                index_col=[0]))
# Out:
# <a id="Overall_absth"></a>
# # Overall absth
#           abscom
# g
# 1   1.792420e-23
# 2   1.795384e-22
# 3   1.798354e-21
# 4   1.801328e-20
# 5   1.804307e-19
# 6   1.968183e-19
# 7   2.005604e-18
# 8   8.065117e-19
# 9   8.419143e-18
# 10  8.788709e-17

# %%
def spreadsheet():
    ng = 10
    ng_refs = [3, 2, 5]
    p_refs = [1, 30, 300]
    
    df_abscom = pd.read_csv(os.path.join(crd.rundir, 'abscom.dat'), 
                            sep=r'\s+', index_col=[0])
    
    # absth(g + 1) / absth(g)
    df_abscom_copy = df_abscom.copy()
    df_abscom_copy.index = df_abscom.index + 1
    df_absratio = df_abscom.loc[3:ng] / df_abscom_copy.loc[3:ng]
    df_absratio.columns = ['k(ig+1)/k(ig)']

    df_dgdgs = crd.data['dgdgs'].to_dataframe()
    
    
    df_dgdgs_cumsum = df_dgdgs.cumsum(axis=0)
    df_dgdgs_cumsum.columns = ['dg cumsum', 'dgs cumsum']
    
    data_pref = np.concatenate([p_ref * np.ones((ng_ref,)) 
                                for ng_ref, p_ref 
                                in zip(ng_refs, p_refs)], axis=0)
    df_pref = pd.DataFrame(data_pref[::-1], 
                           index=df_dgdgs.index, columns=['pref'])
    
    df_all = pd.concat([df_abscom, df_absratio,
                        df_dgdgs, df_dgdgs_cumsum,
                        df_pref], axis=1) 
    return df_all

# %%
display.display(display.HTML(climahtml.getHTML_idanchor(s_ggroup_summary)))
display.display(display.Markdown(climahtml.getMarkdown_sectitle(s_ggroup_summary)))
display.display(spreadsheet())
# Out:
# <a id="g-group_summary"></a>
# # g-group summary
#           abscom  k(ig+1)/k(ig)        dg       dgs  dg cumsum  dgs cumsum  \
# g
# 1   1.792420e-23            NaN  0.020712  0.000390   0.020712    0.000390
# 2   1.795384e-22            NaN  0.282879  0.364681   0.303591    0.365072
# 3   1.798354e-21      10.016538  0.407348  0.383477   0.710939    0.748548
# 4   1.801328e-20      10.016538  0.204121  0.178004   0.915061    0.926552
# 5   1.804307e-19      10.016538  0.055864  0.047581   0.970924    0.974134
# 6   1.968183e-19       1.090825  0.020621  0.018237   0.991545    0.992371
# 7   2.005604e-18      10.190132  0.005545  0.004909   0.997091    0.997280
# 8   8.065117e-19       0.402129  0.001985  0.001851   0.999076    0.999131
# 9   8.419143e-18      10.438959  0.000636  0.000620   0.999712    0.999751
# 10  8.788709e-17      10.438959  0.000288  0.000249   1.000000    1.000000
#
#      pref
# g
# 1   300.0
# 2   300.0
# 3   300.0
# 4   300.0
# 5   300.0
# 6    30.0
# 7    30.0
# 8     1.0
# 9     1.0
# 10    1.0

# %%
def load_d_bigsum():
    
    ng = 10
    
    fpath = os.path.join(crd.rundir, 'd_bigsum.dat')
    df = pd.read_csv(fpath, sep=r'\s+', index_col = [0, 1])

    g_layers = [(1, 62), (2, 58)]
    
    writer = pd.ExcelWriter('_'.join(['d_bigsum_absgas',
                                      'ng_{}'.format(ng)])
                            + '.xlsx')
    for g, layer in g_layers:
        df.loc[(g, layer), :].to_excel(writer, 
                                       '({}, {})'.format(g, layer))
        

#load_d_bigsum()

# %%
display.HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>
