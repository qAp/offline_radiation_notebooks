# %%
# %matplotlib inline
import os
import re

import matplotlib
import numpy as np
import pandas as pd
import xarray as xr

import climatools.html.html as climahtml
import climatools.scripts.g1_threshold as scripts

import IPython.display as display

import imp
imp.reload(scripts)
# Out:
# /lfs1/home/jackyu/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1401: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# <module 'climatools.scripts.g1_threshold' from '/lfs1/home/jackyu/climatools/climatools/scripts/g1_threshold.py'>

# %%
# for printing some input parameters

def innames():
    return ['vstar', 'nband', 'nv', 'dv',
            'tsfc',
            'pressure_reference_1',
            'temperature_reference_1', 
            'pressure_reference_2', 
            'temperature_reference_2',
            'ighigh', 
            'ng', 
            'nref',
            'p_refs',
            't_refs',
            'ng_refs',
            'absth',
            'wgt',
            'planck_wgt_flux']


def pattern_assign(name):
    return ''' 
    parameter .* :: \s* &? \s* ({} \s* = .* \n)
    '''.format(name)

def pattern_data(name):
    return '''
    (data [^/{name}]+ {name}[^,] [^/{name}]+ / [^/]+ /)
    '''.format(name=name)

def pattern_atmpro():
    return '''
    (include \s+ '.*\.pro')
    '''


def get_input_params(code, names):
    results = []
    for name in names:
        regex = re.compile(pattern_assign(name), re.VERBOSE)
        results.extend(regex.findall(code))
        
        regex = re.compile(pattern_data(name), re.VERBOSE)
        results.extend(regex.findall(code))
        
    regex = re.compile(pattern_atmpro(), re.VERBOSE)
    results.extend(regex.findall(code))
        
    results = [result.replace('_r8', '') for result in results]
    return results

# %%
analysis = scripts.Analysis()

# %%
crd = analysis.model('crd')
crd.type_model = 'crd'
crd.rundir = os.path.join('/lfs1/home/jackyu/radiation/crd/LW',
                          'examples/separate_g_groups',
                          'study__lblnew_g1_threshold',
                          'h2o',
                          'band02_wn_340_540',
                          'ng_12',
                          'g_descending',
                          'refPTs_P_1_T_250__P_10_T_250__P_500_T_250',
                          'ng_refs_2__2__8',
                          'getabsth_auto__auto__auto',
                          'absth_dlogN_uniform__dlogN_uniform__dlogN_uniform',
                          'wgt_all.5__all.5__all0',
                          'bigsum',
                          'atmpro_mls')
crd.fpath_flux = 'output_fluxg.dat'
crd.fpath_coolr = 'output_coolrg.dat'
crd.linestyle = '-'
crd.load_data()

# %%
crdx_wgt = analysis.model('wgt')
crdx_wgt.type_model = 'crd'
crdx_wgt.rundir = os.path.join('/lfs1/home/jackyu/radiation/crd/LW',
                          'examples/separate_g_groups',
                          'study__lblnew_g1_threshold',
                          'h2o',
                          'band02_wn_340_540',
                          'ng_12',
                          'g_descending',
                          'refPTs_P_1_T_250__P_10_T_250__P_500_T_250',
                          'ng_refs_2__2__8',
                          'getabsth_auto__auto__auto',
                          'absth_dlogN_uniform__dlogN_uniform__dlogN_uniform',
                          'wgt_all.5__all.5__all0',
                          'bigsum',
                          'atmpro_mls')
crdx_wgt.fpath_flux = 'output_xfluxg.dat'
crdx_wgt.fpath_coolr = 'output_xcoolrg.dat'
crdx_wgt.linestyle = '--'
crdx_wgt.load_data()

# %%
fig = analysis.fig_fluxcoolr('fig1')
fig.ggroups = list(range(1, 12 + 1))
fig.vars_plot['flux'] = ['flug', 'fnetg']
fig.vars_plot['cooling rate'] = ['coolrg']
fig.colors['flug'] = 'darkred'
fig.colors['fnetg'] = 'lightcoral'
fig.colors['coolrg'] = 'blue'
fig.varlims_from_indexrange['linear'] = (50, 1050)
fig.varlims_from_indexrange['log'] = (1e-4, 50)

# %%
table_fluxg = analysis.table('table_fluxg')
table_fluxg.sumg = False
table_fluxg.vartype = 'flux'
table_fluxg.at_pressures = crd.data['flux']\
                             .coords['pressure']\
                             .isel(pressure=[0, -1])

table_coolrg = analysis.table('table_coolrg')
table_coolrg.vartype = 'cooling rate'
table_coolrg.sumg = False
table_coolrg.at_pressures = crd.data['cooling rate']\
                               .coords['pressure']\
                               .isel(pressure=[0, -1])

# %%
table_flux = analysis.table('table_flux')
table_flux.sumg = True
table_flux.vartype = 'flux'
table_flux.at_pressures = crd.data['flux']\
                             .coords['pressure']\
                             .isel(pressure=[0, -1])

table_coolr = analysis.table('table_coolr')
table_coolr.vartype = 'cooling rate'
table_coolr.sumg = True
table_coolr.at_pressures = crd.data['cooling rate']\
                              .coords['pressure']\
                              .isel(pressure=[0, -1])

# %%
table_dgdgs = analysis.table('dgdgs')
table_dgdgs.vartype = 'dgdgs'
table_dgdgs.sumg = False

# %%
# print some input parameters

with open(os.path.join(crd.rundir, 'lblnew.f'), 
          mode='r', encoding='utf-8') as f:
    c = f.read()

print('\n\n'.join(get_input_params(c, innames())))
# Out:
# vstar = 340
#
# nband = 200
#
# nv = 200
#
# dv = 0.005
#
# tsfc = 294.0
#
# ng = 12
#
# nref = 3
#
# p_refs = (/ 1,  10, 500 /)
#
# t_refs = (/ 250, 250, 250 /)
#
# ng_refs = (/ 2,   2,   8 /)
#
# data wgt
#      &     /8*0, 4*.5/
#
# planck_wgt_flux = 2
#
# include 'mls75.pro'

# %%
fig.display_hrefanchor()
# Out:
# <a href="#Figure:_flux,_cooling_rate_g-group_1">Figure: flux, cooling rate g-group 1</a>
# <a href="#Figure:_flux,_cooling_rate_g-group_2">Figure: flux, cooling rate g-group 2</a>
# <a href="#Figure:_flux,_cooling_rate_g-group_3">Figure: flux, cooling rate g-group 3</a>
# <a href="#Figure:_flux,_cooling_rate_g-group_4">Figure: flux, cooling rate g-group 4</a>
# <a href="#Figure:_flux,_cooling_rate_g-group_5">Figure: flux, cooling rate g-group 5</a>
# <a href="#Figure:_flux,_cooling_rate_g-group_6">Figure: flux, cooling rate g-group 6</a>
# <a href="#Figure:_flux,_cooling_rate_g-group_7">Figure: flux, cooling rate g-group 7</a>
# <a href="#Figure:_flux,_cooling_rate_g-group_8">Figure: flux, cooling rate g-group 8</a>
# <a href="#Figure:_flux,_cooling_rate_g-group_9">Figure: flux, cooling rate g-group 9</a>
# <a href="#Figure:_flux,_cooling_rate_g-group_10">Figure: flux, cooling rate g-group 10</a>
# <a href="#Figure:_flux,_cooling_rate_g-group_11">Figure: flux, cooling rate g-group 11</a>
# <a href="#Figure:_flux,_cooling_rate_g-group_12">Figure: flux, cooling rate g-group 12</a>
# <a href="#Figure:_flux,_cooling_rate_g-group_total">Figure: flux, cooling rate g-group total</a>

# %%
table_fluxg.display_hrefanchor()
table_coolrg.display_hrefanchor()
table_flux.display_hrefanchor()
table_coolr.display_hrefanchor()
# Out:
# <a href="#Table:_flux._g-groups">Table: flux. g-groups </a>
# <a href="#Table:_cooling_rate._g-groups">Table: cooling rate. g-groups </a>
# <a href="#Table:_flux._g-groups_total">Table: flux. g-groups total</a>
# <a href="#Table:_cooling_rate._g-groups_total">Table: cooling rate. g-groups total</a>

# %%
table_dgdgs.display_hrefanchor()
# Out:
# <a href="#Table:_dgdgs._g-groups">Table: dgdgs. g-groups </a>

# %%
s_abscom = 'Overall absth'
display.HTML(climahtml.getHTML_hrefanchor(s_abscom))
# Out:
# <a href="#Overall_absth">Overall absth</a>

# %%
s_ggroup_summary = 'g-group summary'
display.HTML(climahtml.getHTML_hrefanchor(s_ggroup_summary))
# Out:
# <a href="#g-group_summary">g-group summary</a>

# %%
#for g in range(1, 20 + 1):
#    s = 'Table: cooling rate. g-group {}'.format(g)
#    html = climahtml.getHTML_hrefanchor(s)
#    display.display(display.HTML(html))

# %%
matplotlib.rcParams.update({'font.size': 13,
                            'grid.color': 'black',
                            'axes.facecolor': 'white',
                            'axes.edgecolor': 'black',
                            'ytick.direction': 'out',
                            'ytick.major.size': 6, 'ytick.major.width': 1,
                            'ytick.minor.size': 3, 'ytick.minor.width': 1,
                            'xtick.direction': 'out',
                            'xtick.major.size': 6, 'xtick.major.size': 1,
                            'xtick.minor.size': 3, 'xtick.minor.size': 1}) 

fig.plot(analysis)
# Out:
# <a id="Figure:_flux,_cooling_rate_g-group_1"></a>
# # Figure: flux, cooling rate g-group 1
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# <a id="Figure:_flux,_cooling_rate_g-group_2"></a>
# # Figure: flux, cooling rate g-group 2
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# <a id="Figure:_flux,_cooling_rate_g-group_3"></a>
# # Figure: flux, cooling rate g-group 3
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# <a id="Figure:_flux,_cooling_rate_g-group_4"></a>
# # Figure: flux, cooling rate g-group 4
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# <a id="Figure:_flux,_cooling_rate_g-group_5"></a>
# # Figure: flux, cooling rate g-group 5
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# <a id="Figure:_flux,_cooling_rate_g-group_6"></a>
# # Figure: flux, cooling rate g-group 6
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# <a id="Figure:_flux,_cooling_rate_g-group_7"></a>
# # Figure: flux, cooling rate g-group 7
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# <a id="Figure:_flux,_cooling_rate_g-group_8"></a>
# # Figure: flux, cooling rate g-group 8
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# <a id="Figure:_flux,_cooling_rate_g-group_9"></a>
# # Figure: flux, cooling rate g-group 9
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# <a id="Figure:_flux,_cooling_rate_g-group_10"></a>
# # Figure: flux, cooling rate g-group 10
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# <a id="Figure:_flux,_cooling_rate_g-group_11"></a>
# # Figure: flux, cooling rate g-group 11
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# <a id="Figure:_flux,_cooling_rate_g-group_12"></a>
# # Figure: flux, cooling rate g-group 12
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# <a id="Figure:_flux,_cooling_rate_g-group_total"></a>
# # Figure: flux, cooling rate g-group total
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.
# Warning: yaxis. Min value to be plotted is less or equal to zero. This part will be omitted on a log scale.

# %%
table_fluxg.display_withdiff(analysis, benchmark='crd')
table_coolrg.display_withdiff(analysis, benchmark='crd')
table_flux.display_withdiff(analysis, benchmark='crd')
table_coolr.display_withdiff(analysis, benchmark='crd')
# Out:
# <a id="Table:_flux._g-groups"></a>
# # Table: flux. g-groups
# CRD
#                         flug       fldg      fnetg
# g  pressure level
# 1  0.0      
#    1001.112500 75     0.000000e+00
# 7  0.000312    1     -2.148785e-05
#    1001.112500 75     0.000000e+00
# 8  0.000312    1     -1.360402e-08
#    1001.112500 75     0.000000e+00
# 9  0.000312    1     -1.258720e-04
#    1001.112500 75     0.000000e+00
# 10 0.000312    1      9.076844e-05
#    1001.112500 75     0.000000e+00
# 11 0.000312    1     -3.547219e-03
#    1001.112500 75     0.000000e+00
# 12 0.000312    1     -2.215249e-02
#    1001.112500 75     0.000000e+00
# <a id="Table:_flux._g-groups_total"></a>
# # Table: flux. g-groups total
# CRD
#                      flug       fldg      fnetg
# pressure level
# 0.0      1     -60.314811   0.000000 -60.314811
# 1013.0   76    -82.315794  81.355336  -0.960459
# WGT
#                      flug       fldg      fnetg
# pressure level
# 0.0      1     -60.266839   0.000000 -60.266839
# 1013.0   76    -82.315794  81.681884  -0.633911
# WGT - CRD
#                     flug      fldg     fnetg
# pressure level
# 0.0      1      0.047972  0.000000  0.047972
# 1013.0   76     0.000000  0.326548  0.326548
# <a id="Table:_cooling_rate._g-groups_total"></a>
# # Table: cooling rate. g-groups total
# CRD
#                      coolrg
# pressure    layer
# 0.000312    1      0.213481
# 1001.112500 75     0.140197
# WGT
#                      coolrg
# pressure    layer
# 0.000312    1      0.187092
# 1001.112500 75     0.127069
# WGT - CRD
#                      coolrg
# pressure    layer
# 0.000312    1     -0.026389
# 1001.112500 75    -0.013128

# %%
table_dgdgs.display_dgdgs(crd)
# Out:
# <a id="Table:_dgdgs._g-groups"></a>
# # Table: dgdgs. g-groups
#           dg       dgs
# g
# 1   0.141550  0.145814
# 2   0.329975  0.334770
# 3   0.246500  0.244908
# 4   0.132400  0.129531
# 5   0.093475  0.090606
# 6   0.037650  0.036705
# 7   0.013825  0.013223
# 8   0.001400  0.001303
# 9   0.002025  0.001980
# 10  0.000675  0.000646
# 11  0.000400  0.000393
# 12  0.000125  0.000121

# %%
# read and display overall absth
display.display(
    display.HTML(climahtml.getHTML_idanchor(s_abscom)))
display.display(
    display.Markdown(climahtml.getMarkdown_sectitle(s_abscom)))

display.display(pd.read_csv(os.path.join(crd.rundir, 'abscom.dat'),
                sep=r'\s+',
                index_col=[0]))
# Out:
# <a id="Overall_absth"></a>
# # Overall absth
#           abscom
# g
# 1   0.000000e+00
# 2   2.038066e-23
# 3   1.043964e-22
# 4   5.347525e-22
# 5   2.739177e-21
# 6   1.403096e-20
# 7   7.187115e-20
# 8   3.681475e-19
# 9   1.184411e-19
# 10  7.000170e-19
# 11  1.194085e-18
# 12  7.846472e-18

# %%
def spreadsheet():
    ng = 12
    ng_refs = [2, 2, 8]
    p_refs = [1, 10, 500]
    
    df_abscom = pd.read_csv(os.path.join(crd.rundir, 'abscom.dat'), 
                            sep=r'\s+', index_col=[0])
    
    # absth(g + 1) / absth(g)
    df_abscom_copy = df_abscom.copy()
    df_abscom_copy.index = df_abscom.index + 1
    df_absratio = df_abscom.loc[3:ng] / df_abscom_copy.loc[3:ng]
    df_absratio.columns = ['k(ig+1)/k(ig)']

    df_dgdgs = crd.data['dgdgs'].to_dataframe()
    
    
    df_dgdgs_cumsum = df_dgdgs.cumsum(axis=0)
    df_dgdgs_cumsum.columns = ['dg cumsum', 'dgs cumsum']
    
    data_pref = np.concatenate([p_ref * np.ones((ng_ref,)) 
                                for ng_ref, p_ref 
                                in zip(ng_refs, p_refs)], axis=0)
    df_pref = pd.DataFrame(data_pref[::-1], 
                           index=df_dgdgs.index, columns=['pref'])
    
    df_all = pd.concat([df_abscom, df_absratio,
                        df_dgdgs, df_dgdgs_cumsum,
                        df_pref], axis=1) 
    return df_all

# %%
display.display(display.HTML(climahtml.getHTML_idanchor(s_ggroup_summary)))
display.display(display.Markdown(climahtml.getMarkdown_sectitle(s_ggroup_summary)))
display.display(spreadsheet())
# Out:
# <a id="g-group_summary"></a>
# # g-group summary
#           abscom  k(ig+1)/k(ig)        dg       dgs  dg cumsum  dgs cumsum  \
# g
# 1   0.000000e+00            NaN  0.141550  0.145814   0.141550    0.145814
# 2   2.038066e-23            NaN  0.329975  0.334770   0.471525    0.480584
# 3   1.043964e-22       5.122326  0.246500  0.244908   0.718025    0.725492
# 4   5.347525e-22       5.122327  0.132400  0.129531   0.850425    0.855023
# 5   2.739177e-21       5.122327  0.093475  0.090606   0.943900    0.945629
# 6   1.403096e-20       5.122327  0.037650  0.036705   0.981550    0.982334
# 7   7.187115e-20       5.122326  0.013825  0.013223   0.995375    0.995557
# 8   3.681475e-19       5.122327  0.001400  0.001303   0.996775    0.996860
# 9   1.184411e-19       0.321722  0.002025  0.001980   0.998800    0.998840
# 10  7.000170e-19       5.910255  0.000675  0.000646   0.999475    0.999486
# 11  1.194085e-18       1.705794  0.000400  0.000393   0.999875    0.999879
# 12  7.846472e-18       6.571116  0.000125  0.000121   1.000000    1.000000
#
#      pref
# g
# 1   500.0
# 2   500.0
# 3   500.0
# 4   500.0
# 5   500.0
# 6   500.0
# 7   500.0
# 8   500.0
# 9    10.0
# 10   10.0
# 11    1.0
# 12    1.0

# %%
display.HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>
