# %%
# %matplotlib inline

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from IPython import display

# %%
path_absgas = os.path.join('/nuwa_cluster/home/jackyu/radiation',
                           'crd/LW/examples/separate_g_groups',
                           'absgas.dat')

# %% [markdown]
# ### (P, T) = (500, 250) using 'Steve_latest version_LBL.f'

# %%
df = pd.read_csv(path_absgas, sep=r'\s+')

# %%
df.plot(x='wavenumber', y='absgas', 
        logy=True, grid=True,
        figsize=(10, 8))

# %% [markdown]
# ### (P,T) = (50, 250) using 'Steve_latest version_LBL.f'

# %%
df = pd.read_csv(path_absgas, sep=r'\s+')

# %%
df.plot(x='wavenumber', y='absgas', 
        logy=True, grid=True,
        figsize=(10, 8))

# %% [markdown]
# ### (P,T) = (50, 250)  using '03_lbl_flux_of_g_groups_08-25.f'

# %%
df = pd.read_csv(path_absgas, sep=r'\s+')

# %%
df.plot(x='wavenumber', y='absgas', 
        logy=True, grid=True,
        figsize=(10, 8))

# %%
display.HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>
