# %%
# %pylab inline
from IPython import display
import os
import io
import itertools
import collections
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import importlib

import rtmtools.lblrtm.aerutils as aerutils
import rtmtools.lblrtm.aeranalyse as aeranalyse
import rtmtools.lblrtm.visualisation as viz

import rtmtools.clirad.sw.wrangle as cliradwrangle
import rtmtools.clirad.sw.analyse as cliradanalyse
import rtmtools.clirad.sw.info

import rtmtools.rrtmg.sw.wrangle as rrtmgwrangle
import rtmtools.rrtmg.sw.analyse as rrtmganalyse



importlib.reload(aerutils)
importlib.reload(aeranalyse)
importlib.reload(viz)

importlib.reload(cliradwrangle)
importlib.reload(cliradanalyse)
importlib.reload(rtmtools.clirad.sw.info)

importlib.reload(rrtmgwrangle)
importlib.reload(rrtmganalyse)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['display']
# `%matplotlib` prevents importing * from pylab and numpy
# <module 'rtmtools.rrtmg.sw.analyse' from '/nuwa_cluster/home/jackyu/radiation/rtmtools/rtmtools/rrtmg/sw/analyse.py'>

# %%
# load CRD results

# %%
pathout_crd = '/nuwa_cluster/home/jackyu/radiation/crd/SW/examples/mls75_O3/OUTPUT_CRD.dat'

# %%
pnl_crd = aerutils.OUTPUT_RADSUM_to_pandasPanel(readfrom = pathout_crd, 
                                                signed_fluxes = True)

# %%
df_crd = aeranalyse.sum_OUTPUT_RADSUM_over_wbands(pnl_crd, V1 = 1000., V2 = 57200.)

Pres_crd = df_crd['pressure'].values
fd_crd = df_crd['flux_down'].values

pres_crd = .5 * (df_crd.values[: -1, 0] + df_crd.values[1:, 0])
hr_crd = df_crd['heating_rate'].values[1:]

# %%
# load CLIRAD results

# %%
pathout_clirad = '/nuwa_cluster/home/jackyu/radiation/clirad/SW/examples/mls75_O3/OUTPUT_CLIRAD.dat'
pnl_clirad = cliradswrangle.OUTPUT_CLIRAD_to_PandasPanel(readfrom = pathout_clirad)
df_clirad = cliradanalyse.sum_OUTPUT_CLIRAD_over_wbands(pnl_clirad, wbands = range(1, 9))

Pres_clirad = df_clirad['pressure'].values
fd_clirad = df_clirad['flux_down'].values

pres_clirad = .5 * (df_clirad.values[: -1, 0] + df_clirad.values[1:, 0])
hr_clirad = df_clirad.values[1:, -1]

# %%
# load CLIRAD results (yihsuan's results from his f90 version)

# %%
pathout_clirad1 = '/nuwa_cluster/home/ignorant/test/pp-clirad_rrtmg/SW/data/output-sw-mls-clirad-only-o3.txt'

df_clirad1 = cliradwrangle.output_txtfile_to_DataFrame(readfrom = pathout_clirad1)

pres_clirad1 = .5 * (df_clirad1.values[: -1, 0] + df_clirad1.values[1:, 0])
hr_clirad1 = df_clirad1.values[1:, -1]

# %%
# load AER's RRTMG results

# %%
pathout_rrtmg = '/nuwa_cluster/home/jackyu/radiation/rrtmg/SW/examples/mls_71lvls_O3/OUTPUT_RRTM'
pnl_rrtmg = rrtmgwrangle.OUTPUT_RRTM_to_pandasPanel(readfrom = pathout_rrtmg, signed_fluxes = True)
df_rrtmg = rrtmganalyse.sum_OUTPUT_RRTM_over_wbands(pnl_rrtmg, V1 = 820., V2 = 50000.)

Pres_rrtmg = df_rrtmg['pressure'].values
fd_rrtmg = df_rrtmg['flux_down'].values

pres_rrtmg = .5 * (df_rrtmg.values[: -1, 0] + df_rrtmg.values[1:, 0])
hr_rrtmg = df_rrtmg['heating_rate'].values[1:]
# Out:
# 0 13

# %%
# Plot downward flux

# %%
matplotlib.rcParams.update({'font.size': 20})
fig = plt.figure(figsize = (12, 12))
ax = fig.add_subplot(111,
                     title = 'Downward flux. $O_3$',
                     xlabel = 'Flux [$W m^{-2}$]',
                     ylabel = 'pressure [mb]')

lines = ax.plot(fd_crd, Pres_crd,
                fd_clirad / fd_clirad[0] * fd_crd[0], Pres_clirad,
                fd_rrtmg / fd_rrtmg[0] * fd_crd[0], Pres_rrtmg)

ax.set_yscale('log')
#ax.set_xlim(left = 520., right = 690.)
#ax.set_ylim(bottom = 0., top = 1020.)
#ax.set_xlim(left = 670., right = 685.)
#ax.set_ylim(bottom = 0., top = 100.)

linestyles = ['-', '--', '--']
colours   = ['b', 'b', 'g']

[plt.setp(line, linestyle = style, color= colour, linewidth = 2.)\
 for line, style, colour in zip(lines, linestyles, colours)]

plt.grid(b = True)
plt.legend(['CRD', 'CLIRAD', 'AER RRTMG',], loc = 'best')
plt.gca().invert_yaxis()

# %%
matplotlib.rcParams.update({'font.size': 20})
fig = plt.figure(figsize = (12, 12))
ax = fig.add_subplot(111,
                     title = 'Heating rate $O_3$',
                     xlabel = 'heating rate [deg/day]',
                     ylabel = 'pressure [mb]')

lines = ax.semilogy(hr_crd, pres_crd,
                    hr_clirad, pres_clirad,
                    hr_rrtmg, pres_rrtmg,
                    hr_clirad1, pres_clirad1)

ax.xaxis.get_major_formatter().set_powerlimits((0, 1))

ax.set_yscale('log')
#ax.set_ylim(bottom = 0., top = 1020.)
#ax.set_xlim(left = 0, right = 2.)

linestyles = ['-', '--', '--', '--']
colours    = ['b', 'b', 'g', 'r']

[plt.setp(line, linestyle = style, color = colour, linewidth = 2.) \
for line, style, colour in zip(lines, linestyles, colours)]

plt.grid(b = True)
plt.legend(['CRD', 'CLIRAD', 'AER RRTMG', 'CLIRAD 1'], loc = 'best')
plt.gca().invert_yaxis()

# %% [markdown]
# # In RRTMG's wavenubmer bands

# %%
levels =  [70, 30, 0]
attrs = ['pressure', 'flux_up', 'flux_down', 'net_flux', 'heating_rate']
name_molecule = '$O_3$'

# %%
crd_wrt_rrtmg = aeranalyse.lines2bands(pnl_crd, wbands = pnl_rrtmg.items)
crd_wrt_rrtmg_lvls = crd_wrt_rrtmg.ix[:, levels, :]

# %%
rrtmg_wrt_rrtmg = pnl_rrtmg.ix[:, :, attrs]
rrtmg_wrt_rrtmg = aeranalyse.normalise_by_TOA_flux_down(rrtmg_wrt_rrtmg, 
                                                        normalise_to = crd_wrt_rrtmg)
rrtmg_wrt_rrtmg_lvls = rrtmg_wrt_rrtmg.ix[:, levels, :]

# %%
df1 = aeranalyse.sum_OUTPUT_RADSUM_over_wbands(crd_wrt_rrtmg, 
                                               V1 = crd_wrt_rrtmg.items[0][0],
                                               V2 = crd_wrt_rrtmg.items[-1][-1])
df2 = aeranalyse.sum_OUTPUT_RADSUM_over_wbands(rrtmg_wrt_rrtmg, 
                                               V1 = rrtmg_wrt_rrtmg.items[0][0],
                                               V2 = rrtmg_wrt_rrtmg.items[-1][-1])

df1_lvls = df1.ix[levels, :]
df2_lvls = df2.ix[levels, :]

viz.tabulate_difference(dfs = [df1_lvls, df2_lvls], 
                        names = ['CRD', 'RRTMG'],
                        title = 'Wavenumber range: {} ~ {} cm-1'.\
                        format(pnl_rrtmg.items[0][0], pnl_rrtmg.items[-1][-1]))

viz.plot_pres_vs_flux_down(dfs = [df1, df2],
                           names = ['CRD', 'RRTMG'], 
                           linestyles = ['-', '--'], 
                           colours = ['b', 'g'],
                           pres_scale = 'log',
                           title = 'Flux down {}. {} ~ {} cm-1'.\
                           format(name_molecule, pnl_rrtmg.items[0][0], pnl_rrtmg.items[-1][-1]))

display.display(plt.gcf()); plt.close()

viz.plot_pres_vs_hrcr(dfs = [df1, df2],
                      names = ['CRD', 'RRTMG'],
                      linestyles = ['-', '--'],
                      colours = ['b', 'g'],
                      pres_scale = 'log',
                      title = 'Heating rate {}. {} ~ {} cm-1'.\
                      format(name_molecule, pnl_rrtmg.items[0][0], pnl_rrtmg.items[-1][-1]))

display.display(plt.gcf()); plt.close()

print()
print('--------------------------------------------------------------------')
print()


for item in pnl_rrtmg.items:
    df1_lvls = crd_wrt_rrtmg_lvls[item]
    df2_lvls = rrtmg_wrt_rrtmg_lvls[item]
   
    df1 = crd_wrt_rrtmg[item]
    df2 = rrtmg_wrt_rrtmg[item]
    
    viz.tabulate_difference(dfs = [df1_lvls, df2_lvls], 
                            names = ['CRD', 'RRTMG'],
                            title = 'Wavenumber band: {} ~ {} cm-1'.format(*item))
    
    
    
    viz.plot_pres_vs_flux_down(dfs = [df1, df2],
                               names = ['CRD', 'RRTMG'],
                               linestyles = ['-', '--'], 
                               colours = ['b', 'g'],
                               pres_scale = 'log',
                               title = 'Flux down {}. {} ~ {} cm-1'.format(name_molecule, *item))
    
    display.display(plt.gcf()); plt.close()

    viz.plot_pres_vs_hrcr(dfs = [df1, df2],
                          names = ['CRD', 'RRTMG'],
                          linestyles = ['-', '--'], 
                           colours = ['b', 'g'],
                           pres_scale = 'log',
                          title = 'Heating rate {}. {} ~ {} cm-1'.format(name_molecule, *item))
    
    display.display(plt.gcf()); plt.close()
    
    print()
    print('--------------------------------------------------------------------')
    print()
# Out:
# Wavenumber range: 820.0 ~ 50000.0 cm-1
#
# CRD
#        pressure  flux_up   flux_down    net_flux  heating_rate
# 70     0.002417        0  682.589066  682.589066      2.196562
# 30   299.800000        0  660.668469  660.668469      0.034653
# 0   1013.000000        0  659.453418  659.453418      0.007995
#
# RRTMG
#       pressure   flux_up   flux_down    net_flux  heating_rate
# 70     0.00242 -0.000199  682.589066  682.588867       0.00000
# 30   299.70000  0.000000  660.686868  660.686868       0.03465
# 0   1013.00000  0.000000  659.502808  659.502808       0.00817
#
# CRD - RRTMG
#     pressure   flux_up  flux_down  net_flux  heating_rate
# 70 -0.000003  0.000199    0.00000  0.000199      2.196562
# 30  0.100000  0.000000   -0.01840 -0.018400      0.000003
# 0   0.000000  0.000000   -0.04939 -0.049390     -0.000175
# --------------------------------------------------------------------
#
#
# Wavenumber band: 820.0 ~ 2600.0 cm-1
#
# CRD
# ...

# %% [markdown]
# # In CLIRAD's wavenumber bands

# %%
cliradsw_wbands = rtmtools.clirad.sw.info.wavenumber_bands()

# %%
levels = [70, 30, 0]
attrs = ['pressure', 'flux_up', 'flux_down', 'net_flux', 'heating_rate']
name_molecule = '$O_3$'
wbands = list(range(1, 8 + 1))
wranges = {wband: cliradsw_wbands[wband] for wband in wbands}

# %%
crd_wrt_clirad = rtmtools.clirad.sw.analyse.lines2bands(pnl_crd, wbands = wranges)
crd_wrt_clirad_lvls = crd_wrt_clirad.ix[:, levels, :]

# %%
clirad_wrt_clirad = pnl_clirad.ix[:, :, attrs]
aeranalyse.normalise_by_TOA_flux_down(clirad_wrt_clirad,
                                      normalise_to = crd_wrt_clirad)
clirad_wrt_clirad_lvls = clirad_wrt_clirad.ix[:, levels, :]

# %%
df1 = cliradanalyse.sum_OUTPUT_CLIRAD_over_wbands(crd_wrt_clirad, wbands = range(1, 8 + 1))
df2 = cliradanalyse.sum_OUTPUT_CLIRAD_over_wbands(clirad_wrt_clirad, wbands = range(1, 8 + 1))

df1_lvls = df1.ix[levels, :]
df2_lvls = df2.ix[levels, :]

wlabel = ' '.join(['{} ~ {}'.format(*interval) \
                   for key, intervals in wranges.items() \
                   for interval in intervals]) + ' cm-1'

viz.tabulate_difference(dfs = [df1_lvls, df2_lvls], 
                        names = ['CRD', 'CLIRAD'],
                        title = 'Wavenumber range: bands {} ~ {}, {}'.\
                        format(wbands[0], wbands[-1], wlabel))
    
viz.plot_pres_vs_flux_down(dfs = [df1, df2],
                           names = ['CRD', 'CLIRAD'],
                           linestyles = ['-', '--'],
                           colours = ['b', 'b'],
                           pres_scale = 'log',
                           title = 'Flux down {}'.format(name_molecule))

display.display(plt.gcf()); plt.close()

viz.plot_pres_vs_hrcr(dfs = [df1, df2],
                      names = ['CRD', 'CLIRAD'],
                      linestyles = ['-', '--'],
                      colours = ['b', 'b'],
                      pres_scale = 'log',
                      title = 'Heating rate {}'.format(name_molecule))

display.display(plt.gcf()); plt.close()

print()
print('--------------------------------------------------------------------')
print()


for wband in wbands:
    df1_lvls = crd_wrt_clirad_lvls[wband]
    df2_lvls = clirad_wrt_clirad_lvls[wband]
    
    df1 = crd_wrt_clirad[wband]
    df2 = clirad_wrt_clirad[wband]
    
    wlabel = ' '.join(['{} ~ {}'.format(*interval) for interval in wranges[wband]]) + ' cm-1'
    
    viz.tabulate_difference(dfs = [df1_lvls, df2_lvls], 
                            names = ['CRD', 'CLIRAD'],
                            title = 'Wavenumber band: {}, {}'.format(wband, wlabel))
    
    viz.plot_pres_vs_flux_down(dfs = [df1, df2],
                               names = ['CRD', 'CLIRAD'],
                               linestyles = ['-', '--'],
                               colours = ['b', 'b'],
                               pres_scale = 'log',
                               title = 'Flux down {} {}'.format(name_molecule, wlabel))
    
    display.display(plt.gcf()); plt.close()

    viz.plot_pres_vs_hrcr(dfs = [df1, df2],
                          names = ['CRD', 'CLIRAD'],
                          linestyles = ['-', '--'],
                          colours = ['b', 'b'],
                          pres_scale = 'log',
                          title = 'Heating rate {} {}'.format(name_molecule, wlabel))
    
    display.display(plt.gcf()); plt.close()
    
    print()
    print('--------------------------------------------------------------------')
    print()
# Out:
# Wavenumber range: bands 1 ~ 8, 35088 ~ 44444 33333 ~ 35088 44444 ~ 57142 30770 ~ 33333 25000 ~ 30770 14286 ~ 25000 8200 ~ 14280 4400 ~ 8200 1000 ~ 4400 cm-1
#
# CRD
#        pressure  flux_up   flux_down    net_flux  heating_rate
# 70     0.002417        0  682.424614  682.424614      2.197931
# 30   299.800000        0  660.465606  660.465606      0.034645
# 0   1013.000000        0  659.250822  659.250822      0.007993
#
# CLIRAD
#        pressure   flux_up   flux_down    net_flux  heating_rate
# 70     0.002417  0.000255  682.424209  682.423887      3.624804
# 30   299.800000  0.000109  660.245149  660.245048      0.036107
# 0   1013.000000  0.000000  658.981731  658.981731      0.008285
#
# CRD - CLIRAD
#     pressure   flux_up  flux_down  net_flux  heating_rate
# 70         0 -0.000255   0.000405  0.000727     -1.426873
# 30         0 -0.000109   0.220458  0.220558     -0.001462
# 0          0  0.000000   0.269091  0.269091     -0.000291
# ...
