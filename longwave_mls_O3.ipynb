# %%
# %pylab inline
import os
import io
import itertools
import collections
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import importlib

import rtmtools.lblrtm.aerutils as aerutils
import rtmtools.lblrtm.aeranalyse as aeranalyse
import rtmtools.lblrtm.visualisation as viz

import rtmtools.clirad.sw.wrangle as cliradwrangle
import rtmtools.clirad.sw.analyse as cliradanalyse
import rtmtools.clirad.lw.info

import rtmtools.rrtmg.lw.wrangle as rrtmgwrangle
import rtmtools.rrtmg.sw.analyse as rrtmganalyse



importlib.reload(aerutils)
importlib.reload(aeranalyse)
importlib.reload(viz)

importlib.reload(cliradwrangle)
importlib.reload(cliradanalyse)
importlib.reload(rtmtools.clirad.lw.info)

importlib.reload(rrtmgwrangle)
importlib.reload(rrtmganalyse)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <module 'rtmtools.rrtmg.sw.analyse' from '/nuwa_cluster/home/jackyu/radiation/rtmtools/rtmtools/rrtmg/sw/analyse.py'>

# %% [markdown]
# #### Load CRD results

# %%
# Get lbl line-by-line results
pathout_crd = '/nuwa_cluster/home/jackyu/radiation/crd/LW/examples/lbl_H2008_O3_cut25/OUTPUT_RADSUM'

pnl_crd = aerutils.OUTPUT_RADSUM_to_pandasPanel(readfrom = pathout_crd, cooling_rate = True, signed_fluxes = True)

outrad = aeranalyse.sum_OUTPUT_RADSUM_over_wbands(pnl_crd, V1 = 0, V2 = 3000)
cor_lbl = outrad.ix[outrad.index[1:], 'cooling_rate']
pres_lbl = .5 * (outrad.values[1:, 0] + outrad.values[:-1, 0])

# %% [markdown]
# #### Load CLIRAD results

# %%
# Read from OUTPUT_CLIRAD.dat
pathout_clirad = '/nuwa_cluster/home/jackyu/radiation/clirad/LW/examples/mls75_O3/OUTPUT_CLIRAD.dat'
pnl_clirad = cliradwrangle.OUTPUT_CLIRAD_to_PandasPanel(readfrom = pathout_clirad, cooling_rate = True, signed_fluxes= True)

df_clirad = cliradanalyse.sum_OUTPUT_CLIRAD_over_wbands(pnl_clirad, wbands=range(1, 11),\
                                                        names = ['flux_up', 'flux_down', 'net_flux', 'cooling_rate'])
pres_clirad = .5 * (df_clirad.values[: -1, 0] + df_clirad.values[1:, 0])
cor_clirad = df_clirad.values[1:, -1]

# %% [markdown]
# #### Load LBLRTM results

# %%
# Get AER line-by-line results
pathout_lblrtm = '/nuwa_cluster/home/jackyu/line_by_line/aerlbl_v12.2_package/runs/LW/run_mls75pro_O3/OUTPUT_RADSUM'
pnl_lblrtm = aerutils.OUTPUT_RADSUM_to_pandasPanel(readfrom = pathout_lblrtm, signed_fluxes = True, cooling_rate = True)


outrad = aeranalyse.sum_OUTPUT_RADSUM_over_wbands(pnl_lblrtm, V1 = 0, V2 = 3000)
cor_lblrtm = outrad.ix[outrad.index[1:], 'cooling_rate']
pres_lblrtm = .5 * (outrad.values[1:, 0] + outrad.values[:-1, 0])

# %% [markdown]
# #### Load RRTMG results

# %%
pathout_rrtmg = '/nuwa_cluster/home/jackyu/radiation/rrtmg/LW/examples/mls70_O3/OUTPUT_RRTM'
pnl_rrtmg = rrtmgwrangle.OUTPUT_RRTM_to_pandasPanel(readfrom = pathout_rrtmg, signed_fluxes = True, cooling_rate = True)


outrad = rrtmganalyse.sum_OUTPUT_RRTM_over_wbands(pnl_rrtmg, V1 = 0, V2 = 3000, \
                                                  names = ['flux_up', 'flux_down', 'net_flux', 'cooling_rate'])
cor_rrtmg = outrad.ix[outrad.index[1:], 'cooling_rate']
pres_rrtmg = .5 * (outrad.values[1:, 0] + outrad.values[:-1, 0])
# Out:
# 0 15

# %% [markdown]
# #### Plot cooling rates

# %%
matplotlib.rcParams.update({'font.size': 20.})
fig = plt.figure(figsize = (10, 10))

ax = fig.add_subplot(111,\
                     xlabel = 'cooling rate [deg/day]',
                     ylabel = 'pressure [mb]',
                     title = 'Cooling rates. $CO_2$')

#items = [ax.xaxis.label, ax.yaxis.label] + ax.get_xticklabels() + ax.get_yticklabels()
#[item.set_fontsize(20) for item in items]

lines = ax.plot(cor_lbl, pres_lbl, \
                    cor_clirad, pres_clirad,
                    cor_lblrtm, pres_lblrtm,
                    cor_rrtmg, pres_rrtmg)

ax.set_yscale('log')

plt.grid(b = True)
plt.gca().invert_yaxis()

colours = ['b'] * 2 + ['g'] * 2
linestyles = ['-', '--', '-', '--',]
[plt.setp(line, color = colour, linestyle = linestyle, linewidth = 1.5) \
 for line, colour, linestyle in zip(lines, colours, linestyles) ]

plt.legend(['CRD', 'CLIRAD', 'AER LBLRTM', 'AER RRTMG'], loc = 'best')

# %% [markdown]
# # CRD vs AER RRTMG

# %%
levels =  [70, 30, 0]
attrs = ['pressure', 'flux_up', 'flux_down', 'net_flux', 'cooling_rate']
name_molecule = '$O_3$'

# %%
crd_wrt_rrtmg = aeranalyse.lines2bands(pnl_crd, wbands = pnl_rrtmg.items)
crd_wrt_rrtmg_lvls = crd_wrt_rrtmg.ix[:, levels, :]

# %%
rrtmg_wrt_rrtmg = pnl_rrtmg.ix[:, :, attrs]
rrtmg_wrt_rrtmg_lvls = rrtmg_wrt_rrtmg.ix[:, levels, :]

# %%
df1 = aeranalyse.sum_OUTPUT_RADSUM_over_wbands(crd_wrt_rrtmg, 
                                               V1 = crd_wrt_rrtmg.items[0][0],
                                               V2 = crd_wrt_rrtmg.items[-1][-1])
df2 = aeranalyse.sum_OUTPUT_RADSUM_over_wbands(rrtmg_wrt_rrtmg,
                                               V1 = rrtmg_wrt_rrtmg.items[0][0],
                                               V2 = rrtmg_wrt_rrtmg.items[-1][-1])

df1_lvls = df1.ix[levels, :]
df2_lvls = df2.ix[levels, :]

viz.tabulate_difference(df1 = df1_lvls, df2 = df2_lvls, 
                        names = ['CRD', 'RRTMG'],
                        title = 'Wavenumber range: {} ~ {} cm-1'.\
                        format(pnl_rrtmg.items[0][0], pnl_rrtmg.items[-1][-1]))


viz.plot_pres_vs_hrcr(dfs = [df1, df2],
                      names = ['CRD', 'RRTMG'],
                      linestyles = ['-', '--'],
                      colours = ['b', 'g'],
                      title = 'Cooling rate {} {} ~ {} cm-1'.\
                      format(name_molecule, pnl_rrtmg.items[0][0], pnl_rrtmg.items[-1][-1]),
                      cooling_rate = True)

print()
print('--------------------------------------------------------------------')
print()


for item in pnl_rrtmg.items:
    df1_lvls = crd_wrt_rrtmg_lvls[item]
    df2_lvls = rrtmg_wrt_rrtmg_lvls[item]
   
    df1 = crd_wrt_rrtmg[item]
    df2 = rrtmg_wrt_rrtmg[item]
    
    viz.tabulate_difference(df1 = df1_lvls, df2 = df2_lvls, 
                            names = ['CRD', 'RRTMG'],
                            title = 'Wavenumber band: {} ~ {} cm-1'.format(*item))
    
    

    viz.plot_pres_vs_hrcr(dfs = [df1, df2],
                          names = ['CRD', 'RRTMG'],
                          linestyles = ['-', '--'], 
                          colours = ['b', 'g'],
                          title = 'Cooling rate {} {} ~ {} cm-1'.format(name_molecule, *item),
                          cooling_rate = True)
    print()
    print('--------------------------------------------------------------------')
    print()
# Out:
# Wavenumber range: 10.0 ~ 3250.0 cm-1
# CRD
#        pressure     flux_up  flux_down    net_flux  cooling_rate
# 70     0.002417 -415.381402   0.000000 -415.381402      0.000000
# 30   299.800000 -421.718210   2.063563 -419.654646     -0.059957
# 0   1013.000000 -423.659523   4.378191 -419.281332      0.026399
# RRTMG
#       pressure   flux_up  flux_down  net_flux  cooling_rate
# 70     0.00242 -412.7006     0.0000 -412.7006       0.00000
# 30   299.70000 -421.4352     3.0272 -418.4080      -0.06896
# 0   1013.00000 -423.5988     5.7209 -417.8779       0.03329
# CRD - RRTMG
#     pressure   flux_up  flux_down  net_flux  cooling_rate
# 70 -0.000003 -2.680802   0.000000 -2.680802      0.000000
# 30  0.100000 -0.283010  -0.963637 -1.246646      0.009003
# 0   0.000000 -0.060723  -1.342709 -1.403432     -0.006891
# --------------------------------------------------------------------
#
#
# Wavenumber band: 10.0 ~ 350.0 cm-1
# CRD
#        pressure    flux_up  flux_down   net_flux  cooling_rate
# 70     0.002417 -54.573788   0.000000 -54.573788  0.000000e+00
# 30   299.800000 -54.573788   0.000000 -54.573787  1.311528e-09
# 0   1013.000000 -54.573788   0.000001 -54.573787  3.837701e-09
# RRTMG
#       pressure  flux_up  flux_down  net_flux  cooling_rate
# 70     0.00242 -54.5825          0  -54.5825            -0
# 30   299.70000 -54.5825          0  -54.5825            -0
# 0   1013.00000 -54.5825          0  -54.5825            -0
# CRD - RRTMG
#     pressure   flux_up  flux_down  net_flux  cooling_rate
# 70 -0.000003  0.008712   0.000000  0.008712  0.000000e+00
# 30  0.100000  0.008712   0.000000  0.008713  1.311528e-09
# 0   0.000000  0.008712   0.000001  0.008713  3.837701e-09
# --------------------------------------------------------------------
#
#
# Wavenumber band: 350.0 ~ 500.0 cm-1
# CRD
#        pressure    flux_up  flux_down   net_flux  cooling_rate
# 70     0.002417 -60.916637   0.000000 -60.916637  0.000000e+00
# 30   299.800000 -60.916638   0.000000 -60.916637  5.833640e-10
# 0   1013.000000 -60.916638   0.000001 -60.916637  4.275775e-09
# RRTMG
#       pressure  flux_up  flux_down  net_flux  cooling_rate
# 70     0.00242 -60.9174          0  -60.9174            -0
# 30   299.70000 -60.9174          0  -60.9174            -0
# 0   1013.00000 -60.9174          0  -60.9174            -0
# CRD - RRTMG
#     pressure   flux_up  flux_down  net_flux  cooling_rate
# 70 -0.000003  0.000763   0.000000  0.000763  0.000000e+00
# 30  0.100000  0.000762   0.000000  0.000763  5.833640e-10
# 0   0.000000  0.000762   0.000001  0.000763  4.275775e-09
# --------------------------------------------------------------------
#
#
# Wavenumber band: 500.0 ~ 630.0 cm-1
# CRD
#        pressure    flux_up  flux_down   net_flux  cooling_rate
# 70     0.002417 -58.652387   0.000000 -58.652387  0.000000e+00
# 30   299.800000 -58.652387   0.000000 -58.652386 -5.988993e-11
# 0   1013.000000 -58.652387   0.000001 -58.652386  4.110279e-09
# RRTMG
#       pressure  flux_up  flux_down  net_flux  cooling_rate
# 70     0.00242 -58.6466          0  -58.6466            -0
# 30   299.70000 -58.6466          0  -58.6466            -0
# 0   1013.00000 -58.6466          0  -58.6466            -0
# CRD - RRTMG
#     pressure   flux_up  flux_down  net_flux  cooling_rate
# 70 -0.000003 -0.005787   0.000000 -0.005787  0.000000e+00
# 30  0.100000 -0.005787   0.000000 -0.005786 -5.988993e-11
# 0   0.000000 -0.005787   0.000001 -0.005786  4.110279e-09
# --------------------------------------------------------------------
#
#
# Wavenumber band: 630.0 ~ 700.0 cm-1
# CRD
#        pressure    flux_up  flux_down   net_flux  cooling_rate
# 70     0.002417 
# CRD
#        pressure   flux_up     flux_down  net_flux  cooling_rate
# 70     0.002417 -0.732844  0.000000e+00 -0.732844  0.000000e+00
# 30   299.800000 -0.732844  5.224365e-10 -0.732844 -4.517531e-11
# 0   1013.000000 -0.732844  2.676597e-09 -0.732844  5.016600e-11
# RRTMG
#       pressure  flux_up  flux_down  net_flux  cooling_rate
# 70     0.00242  -0.7315          0   -0.7315            -0
# 30   299.70000  -0.7315          0   -0.7315            -0
# 0   1013.00000  -0.7316          0   -0.7316            -0
# CRD - RRTMG
#     pressure   flux_up     flux_down  net_flux  cooling_rate
# 70 -0.000003 -0.001344  0.000000e+00 -0.001344  0.000000e+00
# 30  0.100000 -0.001344  5.224365e-10 -0.001344 -4.517531e-11
# 0   0.000000 -0.001244  2.676597e-09 -0.001244  5.016600e-11
# --------------------------------------------------------------------
#
#
# Wavenumber band: 2380.0 ~ 2600.0 cm-1
# CRD
#        pressure   flux_up     flux_down  net_flux  cooling_rate
# 70     0.002417 -0.667119  0.000000e+00 -0.667119  0.000000e+00
# 30   299.800000 -0.667119  4.207911e-10 -0.667119 -4.218625e-11
# 0   1013.000000 -0.667119  2.310911e-09 -0.667119  4.556381e-11
# RRTMG
#       pressure  flux_up  flux_down  net_flux  cooling_rate
# 70     0.00242  -0.5485     0.0000   -0.5485      -0.00000
# 30   299.70000  -0.5700     0.0007   -0.5693      -0.00110
# 0   1013.00000  -0.6658     0.1148   -0.5510       0.00315
# CRD - RRTMG
#     pressure   flux_up  flux_down  net_flux  cooling_rate
# 70 -0.000003 -0.118619     0.0000 -0.118619       0.00000
# 30  0.100000 -0.097119    -0.0007 -0.097819       0.00110
# 0   0.000000 -0.001319    -0.1148 -0.116119      -0.00315
# --------------------------------------------------------------------
#
#
# Wavenumber band: 2600.0 ~ 3250.0 cm-1
# CRD
#        pressure   flux_up     flux_down  net_flux  cooling_rate
# 70     0.002417 -0.404431  0.000000e+00 -0.404431  0.000000e+00
# 30   299.800000 -0.404431  2.104346e-10 -0.404431 -2.639985e-11
# 0   1013.000000 -0.404431  1.291457e-09 -0.404431  2.751858e-11
# RRTMG
#       pressure  flux_up  flux_down  net_flux  cooling_rate
# 70     0.00242  -0.4713          0   -0.4713            -0
# 30   299.70000  -0.4713          0   -0.4713            -0
# 0   1013.00000  -0.4713          0   -0.4713            -0
# CRD - RRTMG
#     pressure   flux_up     flux_down  net_flux  cooling_rate
# 70 -0.000003  0.066869  0.000000e+00  0.066869  0.000000e+00
# 30  0.100000  0.066869  2.104346e-10  0.066869 -2.639985e-11
# 0   0.000000  0.066869  1.291457e-09  0.066869  2.751858e-11
# --------------------------------------------------------------------

# %% [markdown]
# # CRD vs CLIRAD

# %%
clirad_wbands = rtmtools.clirad.lw.info.wavenumber_bands()

# %%
levels = [70, 30, 0]
attrs = ['pressure', 'flux_up', 'flux_down', 'net_flux', 'cooling_rate']
name_molecule = '$O_3$'
wbands = list(range(1, 10 + 1))
wranges = {wband: clirad_wbands[wband] for wband in wbands}

# %%
crd_wrt_clirad = rtmtools.clirad.sw.analyse.lines2bands(pnl_crd, wbands = wranges)
crd_wrt_clirad_lvls = crd_wrt_clirad.ix[:, levels, :]

# %%
clirad_wrt_clirad = pnl_clirad.ix[:, :, attrs]
clirad_wrt_clirad_lvls = clirad_wrt_clirad.ix[:, levels, :]

# %%
df1 = cliradanalyse.sum_OUTPUT_CLIRAD_over_wbands(crd_wrt_clirad, wbands = range(1, 8 + 1),\
                                                  names = attrs[1:])
df2 = cliradanalyse.sum_OUTPUT_CLIRAD_over_wbands(clirad_wrt_clirad, wbands = range(1, 8 + 1),\
                                                  names = attrs[1:])

df1_lvls = df1.ix[levels, :]
df2_lvls = df2.ix[levels, :]

wlabel = ' '.join(['{} ~ {}'.format(*interval) \
                   for key, intervals in wranges.items() \
                   for interval in intervals]) + ' cm-1'

viz.tabulate_difference(df1 = df1_lvls, df2 = df2_lvls, 
                        names = ['CRD', 'CLIRAD'],
                        title = 'Wavenumber range: bands {} ~ {}, {}'.\
                        format(wbands[0], wbands[-1], wlabel))

viz.plot_pres_vs_hrcr(dfs = [df1, df2],
                      names = ['CRD', 'CLIRAD'],
                      linestyles = ['-', '--'],
                      colours = ['b', 'b'],
                      title = 'Cooling rate {}'.format(name_molecule),
                      cooling_rate = True)

print()
print('--------------------------------------------------------------------')
print()


for wband in wbands:
    df1_lvls = crd_wrt_clirad_lvls[wband]
    df2_lvls = clirad_wrt_clirad_lvls[wband]
    
    df1 = crd_wrt_clirad[wband]
    df2 = clirad_wrt_clirad[wband]
    
    wlabel = ' '.join(['{} ~ {}'.format(*interval) for interval in wranges[wband]]) + ' cm-1'
    
    viz.tabulate_difference(df1 = df1_lvls, df2 = df2_lvls, 
                            names = ['CRD', 'CLIRAD'],
                            title = 'Wavenumber band: {}, {}'.format(wband, wlabel))

    viz.plot_pres_vs_hrcr(dfs = [df1, df2],
                          names = ['CRD', 'CLIRAD'],
                          linestyles = ['-', '--'],
                          colours = ['b', 'b'],
                          title = 'Cooling rate {} {}'.format(name_molecule, wlabel),
                          cooling_rate = True)
    print()
    print('--------------------------------------------------------------------')
    print()
# Out:
# Wavenumber range: bands 1 ~ 10, 0 ~ 340 340 ~ 540 540 ~ 800 800 ~ 980 980 ~ 1100 1100 ~ 1215 1215 ~ 1380 1380 ~ 1900 1900 ~ 3000 540 ~ 620 cm-1
# CRD
#        pressure     flux_up  flux_down    net_flux  cooling_rate
# 70     0.002417 -408.758452   0.000000 -408.758452      0.000000
# 30   299.800000 -415.095260   2.063563 -413.031696     -0.059957
# 0   1013.000000 -417.036573   4.378191 -412.658382      0.026399
# CLIRAD
#        pressure    flux_up  flux_down    net_flux  cooling_rate
# 70     0.002417 -407.78516   0.000012 -407.785148     -0.139192
# 30   299.800000 -415.05100   2.313927 -412.737073     -0.058855
# 0   1013.000000 -417.11167   4.914688 -412.196982      0.029646
# CRD - CLIRAD
#     pressure   flux_up  flux_down  net_flux  cooling_rate
# 70         0 -0.973292  -0.000012 -0.973304      0.139192
# 30         0 -0.044260  -0.250364 -0.294623     -0.001102
# 0          0  0.075097  -0.536497 -0.461400     -0.003247
# --------------------------------------------------------------------
#
#
# Wavenumber band: 1, 0 ~ 340 cm-1
# CRD
#        pressure   flux_up  flux_down   net_flux  cooling_rate
# 70     0.002417 -51.09304   0.000000 -51.093040  0.000000e+00
# 30   299.800000 -51.09304   0.000000 -51.093040  1.255140e-09
# 0   1013.000000 -51.09304   0.000001 -51.093039  3.593164e-09
# CLIRAD
#        pressure   flux_up  flux_down   net_flux  cooling_rate
# 70     0.002417 -51.09215   0.000004 -51.092146            -0
# 30   299.800000 -51.09215   0.000004 -51.092146            -0
# 0   1013.000000 -51.09215   0.000004 -51.092146            -0
# CRD - CLIRAD
#     pressure  flux_up  flux_down  net_flux  cooling_rate
# 70         0 -0.00089  -0.000004 -0.000894  0.000000e+00
# 30         0 -0.00089  -0.000004 -0.000894  1.255140e-09
# 0          0 -0.00089  -0.000003 -0.000893  3.593164e-09
# --------------------------------------------------------------------
#
#
# Wavenumber band: 2, 340 ~ 540 cm-1
# CRD
#        pressure    flux_up  flux_down   net_flux  cooling_rate
# 70     0.002417 -82.315834   0.000000 -82.315834  0.000000e+00
# 30   299.800000 -82.315835   0.000000 -82.315834  6.818576e-10
# 0   1013.000000 -82.315835   0.000001 -82.315834  5.776692e-09
# CLIRAD
#        pressure   flux_up  flux_down   net_flux  cooling_rate
# 70     0.002417 -82.31578   0.000004 -82.315776            -0
# 30   299.800000 -82.31578   0.000008 -82.315772            -0
# 0   1013.000000 -82.31578   0.000008 -82.315772            -0
# CRD - CLIRAD
#     pressure   flux_up  flux_down  net_flux  cooling_rate
# 70         0 -0.000054  -0.000004 -0.000058  0.000000e+00
# 30         0 -0.000055  -0.000008 -0.000062  6.818576e-10
# 0          0 -0.000055  -0.000007 -0.000061  5.776692e-09
# --------------------------------------------------------------------
#
#
# Wavenumber band: 3, 540 ~ 800 cm-1
# CRD
#        pressure     flux_up  flux_down    net_flux  cooling_rate
# 70     0.002417 -112.837813   0.000000 -112.837813  0.000000e+00
# 30   299.800000 -112.837813   0.000000 -112.837813 -9.236175e-10
# 0   1013.000000 -112.837813   0.000001 -112.837812  7.897587e-09
# CLIRAD
#        pressure  flux_up  flux_down    net_flux  cooling_rate
# 70     0.002417 -112.816   0.000004 -112.815996            -0
# 30   299.800000 -112.816   0.000008 -112.815992            -0
# 0   1013.000000 -112.816   0.000008 -112.815992            -0
# CRD - CLIRAD
#     pressure   flux_up  flux_down  net_flux  cooling_rate
# 70         0 -0.021813  -0.000004 -0.021817  0.000000e+00
# 30         0 -0.021813  -0.000008 -0.021821 -9.236175e-10
# 0          0 -0.021813  -0.000007 -0.021820  7.897587e-09
# --------------------------------------------------------------------
#
#
# Wavenumber band: 4, 800 ~ 980 cm-1
# CRD
#        pressure    flux_up  flux_down   net_flux  cooling_rate
# 70     0.002417 -61.681242          0 -61.681242  0.000000e+00
# 30   299.800000 -61.681243          0 -61.681243 -1.355153e-09
# 0   1013.000000 -61.681243          0 -61.681242  4.304974e-09
# CLIRAD
#        pressure   flux_up  flux_down  net_flux  cooling_rate
# 70     0.002417 -61.64932          0 -61.64932            -0
# 30   299.800000 -61.64932          0 -61.64932            -0
# 0   1013.000000 -61.64932          0 -61.64932            -0
# CRD - CLIRAD
#     pressure   flux_up  flux_down  net_flux  cooling_rate
# 70         0 -0.031922          0 -0.031922  0.000000e+00
# 30         0 -0.031923          0 -0.031923 -1.355153e-09
# 0          0 -0.031923          0 -0.031922  4.304974e-09
# --------------------------------------------------------------------
#
#
# Wavenumber band: 5, 980 ~ 1100 cm-1
# CRD
#        pressure    flux_up  flux_down   net_flux  cooling_rate
# 70     0.002417 -23.076111   0.000000 -23.076111      0.000000
# 30   299.800000 -29.412917   2.063562 -27.349356     -0.059957
# 0   1013.000000 -31.354231   4.378188 -26.976043      0.026399
# CLIRAD
#        pressure   flux_up  flux_down   net_flux  cooling_rate
# 70     0.002417 -22.01741   0.000000 -22.017410     -0.139192
# 30   299.800000 -29.28325   2.313905 -26.969345     -0.058855
# 0   1013.000000 -31.34392   4.914667 -26.429253      0.029646
# CRD - CLIRAD
#     pressure   flux_up  flux_down  net_flux  cooling_rate
# 70         0 -1.058701  -0.000000 -1.058702      0.139192
# 30         0 -0.129667  -0.250343 -0.380011     -0.001102
# 0          0 -0.010311  -0.536479 -0.546790     -0.003247
# --------------------------------------------------------------------
#
#
# Wavenumber band: 6, 1100 ~ 1215 cm-1
# CRD
#        pressure    flux_up     flux_down   net_flux  cooling_rate
# 70     0.002417 -23.269652  0.000000e+00 -23.269652  0.000000e+00
# 30   299.800000 -23.269652  4.643548e-08 -23.269652 -8.180951e-10
# 0   1013.000000 -23.269652  1.389566e-07 -23.269652  1.618239e-09
# CLIRAD
#        pressure   flux_up  flux_down  net_flux  cooling_rate
# 70     0.002417 -23.27341          0 -23.27341            -0
# 30   299.800000 -23.27341          0 -23.27341            -0
# 0   1013.000000 -23.27341          0 -23.27341            -0
# CRD - CLIRAD
#     pressure   flux_up     flux_down  net_flux  cooling_rate
# 70         0  0.003758  0.000000e+00  0.003758  0.000000e+00
# 30         0  0.003758  4.643548e-08  0.003758 -8.180951e-10
# 0          0  0.003758  1.389566e-07  0.003758  1.618239e-09
# --------------------------------------------------------------------
#
#
# Wavenumber band: 7, 1215 ~ 1380 cm-1
# CRD
#        pressure    flux_up     flux_down   net_flux  cooling_rate
# 70     0.002417 -23.755165  0.000000e+00 -23.755165  0.000000e+00
# 30   299.800000 -23.755165  4.129745e-08 -23.755165 -9.604811e-10
# 0   1013.000000 -23.755165  1.320426e-07 -23.755165  1.648939e-09
# CLIRAD
#        pressure   flux_up  flux_down  net_flux  cooling_rate
# 70     0.002417 -23.74062          0 -23.74062            -0
# 30   299.800000 -23.74062          0 -23.74062            -0
# 0   1013.000000 -23.74062          0 -23.74062            -0
# CRD - CLIRAD
#     pressure   flux_up     flux_down  net_flux  cooling_rate
# 70         0 -0.014545  0.000000e+00 -0.014545  0.000000e+00
# 30         0 -0.014545  4.129745e-08 -0.014545 -9.604811e-10
# 0          0 -0.014545  1.320426e-07 -0.014545  1.648939e-09
# --------------------------------------------------------------------
#
#
# Wavenumber band: 8, 1380 ~ 1900 cm-1
# CRD
#        pressure    flux_up     flux_down   net_flux  cooling_rate
# 70     0.002417 -30.729595  0.000000e+00 -30.729595  0.000000e+00
# 30   299.800000 -30.729595  4.106866e-08 -30.729595 -1.499367e-09
# 0   1013.000000 -30.729595  1.496447e-07 -30.729595  2.124841e-09
# CLIRAD
#        pressure   flux_up  flux_down   net_flux  cooling_rate
# 70     0.002417 -30.88047   0.000000 -30.880470            -0
# 30   299.800000 -30.88047   0.000002 -30.880468            -0
# 0   1013.000000 -30.88047   0.000002 -30.880468            -0
# CRD - CLIRAD
#     pressure   flux_up  flux_down  net_flux  cooling_rate
# 70         0  0.150875  -0.000000  0.150875  0.000000e+00
# 30         0  0.150875  -0.000002  0.150873 -1.499367e-09
# 0          0  0.150875  -0.000002  0.150873  2.124841e-09
# --------------------------------------------------------------------
#
#
# Wavenumber band: 9, 1900 ~ 3000 cm-1
# CRD
#        pressure   flux_up     flux_down  net_flux  cooling_rate
# 70     0.002417 -6.625445  0.000000e+00 -6.625445  0.000000e+00
# 30   299.800000 -6.625445  5.418739e-09 -6.625445 -3.942476e-10
# 0   1013.000000 -6.625445  2.564721e-08 -6.625445  4.544859e-10
# CLIRAD
#        pressure   flux_up     flux_down  net_flux  cooling_rate
# 70     0.002417 -6.674494 -1.536682e-08 -6.674494            -0
# 30   299.800000 -6.674494 -2.533197e-07 -6.674494            -0
# 0   1013.000000 -6.674494 -5.066395e-07 -6.674495            -0
# CRD - CLIRAD
#     pressure   flux_up     flux_down  net_flux  cooling_rate
# 70         0  0.049049  1.536682e-08  0.049049  0.000000e+00
# 30         0  0.049049  2.587384e-07  0.049049 -3.942476e-10
# 0          0  0.049049  5.322867e-07  0.049049  4.544859e-10
# --------------------------------------------------------------------
#
#
# Wavenumber band: 10, 540 ~ 620 cm-1
# CRD
#        pressure   flux_up  flux_down  net_flux  cooling_rate
# 70     0.002417 -36.23542          0 -36.23542  0.000000e+00
# 30   299.800000 -36.23542          0 -36.23542 -7.753076e-11
# 0   1013.000000 -36.23542          0 -36.23542  2.538879e-09
# CLIRAD
#        pressure  flux_up  flux_down  net_flux  cooling_rate
# 70     0.002417       -0          0         0            -0
# 30   299.800000       -0          0         0            -0
# 0   1013.000000       -0          0         0            -0
# CRD - CLIRAD
#     pressure   flux_up  flux_down  net_flux  cooling_rate
# 70         0 -36.23542          0 -36.23542  0.000000e+00
# 30         0 -36.23542          0 -36.23542 -7.753076e-11
# 0          0 -36.23542          0 -36.23542  2.538879e-09
# --------------------------------------------------------------------
