# %%
# %pylab inline
import os
import itertools
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import importlib

import rtmtools.lblrtm.aerutils as aerutils
import rtmtools.lblrtm.aeranalyse as aeranalyse
import rtmtools.rrtmg.lw.wrangle
from rtmtools.rrtmg.lw.wrangle import sum_OUTPUT_RRTM_over_wave_numbers
import rtmtools.clirad.sw.wrangle as cliradwrangle
import rtmtools.clirad.sw.analyse as cliradanalyse

importlib.reload(aerutils)
importlib.reload(aeranalyse)
importlib.reload(rtmtools.rrtmg.lw.wrangle)
from rtmtools.rrtmg.lw.wrangle import sum_OUTPUT_RRTM_over_wave_numbers
importlib.reload(cliradwrangle)
importlib.reload(cliradanalyse)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <module 'rtmtools.clirad.sw.analyse' from '/nuwa_cluster/home/jackyu/radiation/rtmtools/rtmtools/clirad/sw/analyse.py'>

# %% [markdown]
# #### Load CRD results

# %%
# Get lbl line-by-line results
pathout_crd = '/nuwa_cluster/home/jackyu/radiation/crd/LW/examples/lbl_H2008_O3_cut25/OUTPUT_RADSUM'
outrad = aerutils.sum_OUTPUT_RADSUM_over_wave_numbers(readfrom = pathout_crd, V1 = 0, V2 = 3000, cooling_rate = True)
cor_lbl = outrad.ix[outrad.index[1:], 'cooling_rate']
pres_lbl = .5 * (outrad.values[1:, 0] + outrad.values[:-1, 0])
#pressure_lbl = pd.DataFrame(data = pressure_lbl, columns = ['pressure'], index = cor_lbl.index)

# %% [markdown]
# #### Load CLIRAD results

# %%
pathout_clirad = '/nuwa_cluster/home/jackyu/radiation/clirad/LW/examples/mls75_O3/tt-output-now.dat'
with open(pathout_clirad, mode = 'r', encoding = 'utf-8') as file:
    c = file.read()

# %%
layers_between_levels = [line.split()
 for line in c.split('(C/day)')[-1].split('\n') if line and not line.isspace()][:-1]

# %%
data_firstrow = [layers_between_levels[0][1:] + ['nan']]
data_restrows = [lev[1:] + lyr for lyr, lev in itertools.zip_longest(*(2 * [iter(layers_between_levels[1:])]))]
data = np.array(data_firstrow + data_restrows).astype('f8')

# %%
columns = ['pressure', 'flux_up', 'flux_down', 'net_flux', 'dfdts', 'cooling_rate']
outrad = pd.DataFrame(data = data[:: -1],\
                      columns = columns).sort_index(ascending = False)

# %%
pres_clirad = .5 * (outrad.values[: -1, 0] + outrad.values[1:, 0])
cor_clirad  = outrad.values[1:, -1]

# %%
# Read from OUTPUT_CLIRAD.dat
pathout1_clirad = '/nuwa_cluster/home/jackyu/radiation/clirad/LW/examples/mls75_O3/OUTPUT_CLIRAD.dat'
pnl_clirad = cliradwrangle.OUTPUT_CLIRAD_to_PandasPanel(readfrom = pathout1_clirad,
                                                        signed_fluxes = True, cooling_rate = True)
df_clirad = cliradanalyse.sum_OUTPUT_CLIRAD_over_wbands(pnl_clirad, wbands = range(1, 11),
                                                        names = ['flux_up', 'flux_down', 'net_flux', 'cooling_rate'])
pres1_clirad = .5 * (df_clirad.values[: -1, 0] + df_clirad.values[1:, 0])
cor1_clirad = df_clirad.values[1:, -1]

# %% [markdown]
# #### Load LBLRTM results

# %%
# Get AER line-by-line results
pathout_lblrtm = '/nuwa_cluster/home/jackyu/line_by_line/aerlbl_v12.2_package/runs/LW/run_mls75pro_O3/OUTPUT_RADSUM'
outrad = aerutils.sum_OUTPUT_RADSUM_over_wave_numbers(readfrom = pathout_lblrtm, V1 = 0, V2 = 3000, cooling_rate = True)
cor_lblrtm = outrad.ix[outrad.index[1:], 'cooling_rate']
pres_lblrtm = .5 * (outrad.values[1:, 0] + outrad.values[:-1, 0])

# %% [markdown]
# #### Load RRTMG results

# %%
pathout_rrtmg = '/nuwa_cluster/home/jackyu/radiation/rrtmg/LW/examples/mls70_O3/OUTPUT_RRTM'
outrad = sum_OUTPUT_RRTM_over_wave_numbers(readfrom = pathout_rrtmg, V1 = 0, V2 = 3000)
pres_rrtmg = .5 * (outrad.values[1:, 0] + outrad.values[: -1, 0])
cor_rrtmg = outrad.ix[outrad.index[1:], 'cooling_rate']

# %% [markdown]
# #### Plot cooling rates

# %%
matplotlib.rcParams.update({'font.size': 20.})
fig = plt.figure(figsize = (13, 13))
ax = fig.add_subplot(111,
                     xlabel = 'cooling rate [deg/day]', xlim = [-.4, .2],
                     ylabel = 'pressure [mb]', ylim = [1e-4, 1.1e3],
                     title = 'Cooling rates. $O_3$')

lines = ax.plot(cor_lbl, pres_lbl,\
                    cor_clirad, pres_clirad,\
                    cor_lblrtm, pres_lblrtm,\
                    cor_rrtmg, pres_rrtmg,
                    cor1_clirad, pres1_clirad)

colours = ['b'] * 2 + 2 * ['g'] + ['y']
linestyles = ['-', '--'] * 2 + ['--']
[plt.setp(line, linestyle = style, color = colour, linewidth = 1.5)\
for line, style, colour in zip(lines, linestyles, colours)]

plt.legend(['CRD', 'CLIRAD', 'AER LBLRTM', 'AER RRTMG', 'CLIRAD (bandwise)'], loc = 'best')
plt.grid(b = True)
plt.gca().invert_yaxis()

#path_fig = 'cor_mls_O3_linearplot.pdf'
#plt.savefig(path_fig)

# %% [markdown]
# # Cooling rate difference above ~ 100 mb in RRTMG's 16 bands: AER LBLRTM vs AER RRTMG

# %%
orad_rrtmg = rtmtools.rrtmg.lw.wrangle.OUTPUT_RRTM_to_pandasPanel(readfrom = pathout_rrtmg, signed_fluxes=True, cooling_rate=True)

# %%
for V1, V2 in orad_rrtmg.items:
    print('Wave number band {} ~ {} cm-1'.format(V1, V2))
    df_rrtmg = sum_OUTPUT_RRTM_over_wave_numbers(readfrom = pathout_rrtmg, V1 = V1, V2 = V2)
    df_lblrtm = aerutils.sum_OUTPUT_RADSUM_over_wave_numbers(readfrom = pathout_lblrtm, V1 = V1, V2 = V2)
    print(df_rrtmg[df_rrtmg['pressure'] > 100]['cooling_rate'] - df_lblrtm[df_lblrtm['pressure'] > 100]['cooling_rate'])
    print()
    print()
# Out:
# Wave number band 10.0 ~ 350.0 cm-1
# 38    0.020614
# 37    0.025680
# 36    0.030655
# 35    0.036501
# 34    0.045021
# 33    0.056701
# 32    0.070261
# 31    0.083452
# 30    0.095852
# 29    0.107967
# 28    0.119900
# 27    0.131374
# 26    0.143038
# 25    0.154041
# 24    0.164174
# 23    0.174129
# 22    0.183854
# 21    0.192788
# 20    0.200801
# 19    0.208703
# 18    0.216525
# 17    0.223287
# 16    0.229429
# 15    0.235711
# 14    0.241903
# 13    0.247225
# 12    0.251637
# 11    0.256229
# 10    0.261061
# 9     0.265012
# 8     0.268104
# 7     0.271115
# 6     0.273136
# 5     0.275247
# 4     0.274759
# 3     0.275100
# 2     0.274731
# 1     0.275573
# 0     0.245434
# Name: cooling_rate, dtype: float64
# Wave number band 350.0 ~ 500.0 cm-1
# 38    3.896605e-07
# 37    2.798076e-07
# 36    1.917422e-07
# 35    8.960319e-08
# 34   -5.046464e-08
# 33   -2.031172e-07
# 32   -3.421414e-07
# 31   -4.496883e-07
# 30   -5.338283e-07
# 29   -6.135393e-07
# ...
